# %%
URL = f"https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=series5&templateId=web&pool=cbox12&_cv=20230425152100&_callback=jQuery34103220350950592199_1682763418916&lang=ko&country=&objectId={'504107_0'}&categoryId=&pageSize=30&indexSize=5&groupId=&listType=OBJECT&pageType=default&page=1&initialize=true&followSize=5&userType=&useAltSort=true&replyPageSize=10&_=1682763418918"

# %%
header = {
    # "accept": "*/*",
    "referer": f"https://series.naver.com/novel/detail.series?productNo={9620099}", # 지우면 안됨
    # "sec-ch-ua-mobile": "?0",
    # "sec-ch-ua-platform": "Windows",
    # "sec-fetch-dest": "script",
    # "sec-fetch-mode": "no-cors",
    # "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36" # 지우면 안됨
}

# %%
import requests

response = requests.get(URL, headers=header)
data = response.content

# %%
jquery = data.decode(encoding='UTF-8', errors='strict')

# %%
jquery
# Out:
# 'jQuery34103220350950592199_1682763418916({"success":true,"code":"1000","message":"요청을 성공적으로 처리하였습니다.","lang":"ko","country":"UNKNOWN","result":{"commentList":[{"ticket":"series5","objectId":"504107_0","categoryId":"1","templateId":"v2","commentNo":"14044666","parentCommentNo":"14044666","replyLevel":1,"replyCount":7,"replyAllCount":8,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList":null,"imagePathList":null,"imageWidthList":null,"imageHeightList":null,"commentType":"txt","stickerId":null,"sticker":null,"sortValue":1681659825111,"contents":"이건... 내 전문이다.","userIdNo":"6jEDk","exposedUserIp":null,"lang":"ko","country":"KR","idType":"naver","idProvider":"naver","userName":"후회남등짝때리기","userProfileImage":"https://profile-phinf.pstatic.net/00349/871cb00db5c2575c94cc0bee235490368b978458aa904170927f88b7e4087ad7.jpg","profileType":"naver","modTime":"2023-04-17T00:43:45+0900","modTimeGmt":"2023-04-16T15:43:45+0000","regTime":"2023-04-17T00:43:45+0900","regTimeGmt":"2023-04-16T15:43:45+0000","sympathyCount":313,"antipathyCount":24,"hideReplyButton":false,"status":0,"mine":false,"best":true,"mentions":null,"toUser":null,"userStatus":0,"categoryImage":null,"open":false,"levelCode":null,"grades":null,"sympathy":false,"antipathy":false,"metaInfo":null,"extension":null,"translation":null,"report":null,"middleBlindReport":false,"spamInfo":null,"userHomepageUrl":null,"defamation":false,"hiddenByCleanbot":false,"score":0.0,"ratings":null,"following":false,"managerLike":false,"pick":false,"attachmentList":null,"reference":null,"inspectionId":null,"visible":true,"manager":false,"idNo":"6jEDk","deleted":false,"blindReport":false,"expose":true,"maskedUserId":"lsi9****","maskedUserName":"후회****","serviceId":null,"userBlocked":false,"exposeByCountry":false,"profileUserId":null,"blind":false,"secret":false,"validateBanWords":false,"containText":true,"virtual":false,"originalStatus":0,"anonymous":false},{"ticket":"series5","objectId":"504107_0","categoryId":"34","templateId":"v2","commentNo":"14047515","parentCommentNo":"14047515","replyLevel":1,"replyCount":6,"replyAllCount":7,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList":null,"imagePathList":null,"imageWidthList":null,"imageHeightList":null,"commentType":"txt","stickerId":null,"sticker":null,"sortValue":1681696689248,"contents":"왜꼭 필요한 장면아닌가요. 과거가 나와야 아 그래서 이랬구나가 되죠 자꾸 가볍게 가볍게 빠르게 빠르게만 요구하니 마구잡이식 양산형 소설만 쏟아지죠. ","userIdNo":"UAhw","exposedUserIp":null,"lang":"ko","country":"KR","idType":"naver","idProvider":"naver","userName":"여보세요","userProfileImage":"https://profile-phinf.pstatic.net/15292/bb32e28f0826f17f4f9f290309dc1ef081bdbcc9d65a54c7d9ace04f69897e1b.jpg","profileType":"naver","modTime":"2023-04-17T10:58:09+0900","modTimeGmt":"2023-04-17T01:58:09+0000","regTime":"2023-04-17T10:58:09+0900","regTimeGmt":"2023-04-17T01:58:09+0000","sympathyCount":265,"antipathyCount":13,"hideReplyButton":false,"status":0,"mine":false,"best":true,"mentions":null,"toUser":null,"userStatus":0,"categoryImage":null,"open":false,"levelCode":null,"grades":null,"sympathy":false,"antipathy":false,"metaInfo":null,"extension":null,"translation":null,"report":null,"middleBlindReport":false,"spamInfo":null,"userHomepageUrl":null,"defamation":false,"hiddenByCleanbot":false,"score":0.0,"ratings":null,"following":false,"managerLike":false,"pick":false,"attachmentList":null,"reference":null,"inspectionId":null,"visible":true,"manager":false,"idNo":"UAhw","deleted":false,"blindReport":false,"expose":true,"maskedUserId":"slsp****","maskedUserName":"여보****","serviceId":null,"userBlocked":false,"exposeByCountry":false,"profileUserId":null,"blind":false,"secret":false,"validateBanWords":false,"containText":true,"virtual":false,"originalStatus":0,"anonymous":false},{"ticket":"series5","objectId":"504107_0","categoryId":"9","templateId":"v2","commentNo":"14045275","parentCommentNo":"14045275","replyLevel":1,"replyCount":1,"replyAllCount":2,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList": ...

# %%
start = jquery.find('{')

# %%
end = jquery[::-1].find("}")

# %%
json_data = jquery[start : -end]

# %%
import json
dict_data = json.loads(json_data)

# %%
dict_data
# Out:
# {'success': True,
#  'code': '1000',
#  'message': '요청을 성공적으로 처리하였습니다.',
#  'lang': 'ko',
#  'country': 'UNKNOWN',
#  'result': {'commentList': [{'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '1',
#     'templateId': 'v2',
#     'commentNo': '14044666',
#     'parentCommentNo': '14044666',
#     'replyLevel': 1,
#     'replyCount': 7,
#     'replyAllCount': 8,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681659825111,
#     'contents': '이건... 내 전문이다.',
#     'userIdNo': '6jEDk',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '후회남등짝때리기',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/00349/871cb00db5c2575c94cc0bee235490368b978458aa904170927f88b7e4087ad7.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T00:43:45+0900',
#     'modTimeGmt': '2023-04-16T15:43:45+0000',
#     'regTime': '2023-04-17T00:43:45+0900',
#     'regTimeGmt': '2023-04-16T15:43:45+0000',
#     'sympathyCount': 313,
#     'antipathyCount': 24,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '6jEDk',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'lsi9****',
#     'maskedUserName': '후회****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '34',
#     'templateId': 'v2',
#     'commentNo': '14047515',
#     'parentCommentNo': '14047515',
#     'replyLevel': 1,
#     'replyCount': 6,
#     'replyAllCount': 7,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681696689248,
#     'contents': '왜꼭 필요한 장면아닌가요. 과거가 나와야 아 그래서 이랬구나가 되죠 자꾸 가볍게 가볍게 빠르게 빠르게만 요구하니 마구잡이식 양산형 소설만 쏟아지죠. ',
#     'userIdNo': 'UAhw',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '여보세요',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/15292/bb32e28f0826f17f4f9f290309dc1ef081bdbcc9d65a54c7d9ace04f69897e1b.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T10:58:09+0900',
#     'modTimeGmt': '2023-04-17T01:58:09+0000',
#     'regTime': '2023-04-17T10:58:09+0900',
#     'regTimeGmt': '2023-04-17T01:58:09+0000',
#     'sympathyCount': 265,
#     'antipathyCount': 13,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'UAhw',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'slsp****',
#     'maskedUserName': '여보****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '9',
#     'templateId': 'v2',
#     'commentNo': '14045275',
#     'parentCommentNo': '14045275',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 2,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681664279277,
#     'contents': '여주한테 돌을 던질만큼 저 사람들이 모두 깨끗한가? 결국 화풀이 할 인질이 필요했고 약한 여주만 고통을 다 겪네요..',
#     'userIdNo': 'aC5Xp',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'Flowertomool',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/36447/1011f77605ece098ad42084262333d82dfb1daab8d9f97fcdcdc958bd19640ac.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T01:57:59+0900',
#     'modTimeGmt': '2023-04-16T16:57:59+0000',
#     'regTime': '2023-04-17T01:57:59+0900',
#     'regTimeGmt': '2023-04-16T16:57:59+0000',
#     'sympathyCount': 232,
#     'antipathyCount': 20,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'aC5Xp',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'hele****',
#     'maskedUserName': 'Fl****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '1',
#     'templateId': 'v2',
#     'commentNo': '14055590',
#     'parentCommentNo': '14055590',
#     'replyLevel': 1,
#     'replyCount': 10,
#     'replyAllCount': 10,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681752216009,
#     'contents': '선발대입니다. 근래 런칭된 신작들 중 보기드문 수작입니다. 마법, 회귀, 빙의 없이 근대 배경으로 남주, 여주 둘의 배경값과 사회환경으로 인한 애증, 혐관이 아주 현실적으로 묘사됩니다. 정갈하고 깔끔한 문체가 피폐물 특유의 무거운 분위기를 잘 살려내면서 동시에 스토리라인도 속도감있게 풀어냅니다. 대여권 순식간에 다쓰고 쿠크굽다가 댓글이 너무 적어서 유입이 적을려나 싶어 적극 추천합니다. 매편마다 댓글 달 시간이 없어요. 다음편 누르느라 ㅋㅋㅋ ',
#     'userIdNo': 'hPnj',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'mann****',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/37193/ba54dff8c000e2d41e0612e05310f5bec6509c7305a633b63b538fd68b05c2c3.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-18T02:23:36+0900',
#     'modTimeGmt': '2023-04-17T17:23:36+0000',
#     'regTime': '2023-04-18T02:23:36+0900',
#     'regTimeGmt': '2023-04-17T17:23:36+0000',
#     'sympathyCount': 228,
#     'antipathyCount': 12,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'hPnj',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'mann****',
#     'maskedUserName': 'ma****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '11',
#     'templateId': 'v2',
#     'commentNo': '14048595',
#     'parentCommentNo': '14048595',
#     'replyLevel': 1,
#     'replyCount': 12,
#     'replyAllCount': 12,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681705688720,
#     'contents': '하이너가 아네트 초상화 샀다는 거에 100원 걸겠어요',
#     'userIdNo': 'de0W5',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'bab',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/02424/b9c8873158ed5ff1fb85b23f7f92ad44c0d395f6fbf145edc8db823b595e1b51.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T13:28:09+0900',
#     'modTimeGmt': '2023-04-17T04:28:09+0000',
#     'regTime': '2023-04-17T13:28:09+0900',
#     'regTimeGmt': '2023-04-17T04:28:09+0000',
#     'sympathyCount': 220,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'de0W5',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'baby****',
#     'maskedUserName': 'ba****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '7',
#     'templateId': 'v2',
#     'commentNo': '14045209',
#     'parentCommentNo': '14045209',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681663782019,
#     'contents': '그래 너 힘들었던 거 알겠는데 왜 아무잘못 없는 어주를 괴롭히는데? 나중에 후회하더라도 여주가 안받아줬으면 좋겠어요',
#     'userIdNo': 'aC5Xp',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'Flowertomool',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/36447/1011f77605ece098ad42084262333d82dfb1daab8d9f97fcdcdc958bd19640ac.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T01:49:42+0900',
#     'modTimeGmt': '2023-04-16T16:49:42+0000',
#     'regTime': '2023-04-17T01:49:42+0900',
#     'regTimeGmt': '2023-04-16T16:49:42+0000',
#     'sympathyCount': 215,
#     'antipathyCount': 32,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'aC5Xp',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'hele****',
#     'maskedUserName': 'Fl****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '9',
#     'templateId': 'v2',
#     'commentNo': '14045955',
#     'parentCommentNo': '14045955',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 2,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681674836325,
#     'contents': '세상 깨끗하고 정의로운 척 하는 무리들도 결국 권력을 맞보면 더 타락하게 됨 동서고금 항상 그래왔지',
#     'userIdNo': '3v0wu',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '효성효',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/35152/d96177f66e52bde4455ffa109020f5365a79977034e20330ff9f3e7df23fe7dc.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T04:53:56+0900',
#     'modTimeGmt': '2023-04-16T19:53:56+0000',
#     'regTime': '2023-04-17T04:53:56+0900',
#     'regTimeGmt': '2023-04-16T19:53:56+0000',
#     'sympathyCount': 175,
#     'antipathyCount': 20,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '3v0wu',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'hjag****',
#     'maskedUserName': '효성****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '31',
#     'templateId': 'v2',
#     'commentNo': '14045563',
#     'parentCommentNo': '14045563',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681667312128,
#     'contents': '속도가 미쳤네 이혼완료💔',
#     'userIdNo': '8ajYD',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '요고로케',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/14419/e76943df8fa26802650ec595b966c2cc1edab7b18a005a8b78cbc0cd138c92b4.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T02:48:32+0900',
#     'modTimeGmt': '2023-04-16T17:48:32+0000',
#     'regTime': '2023-04-17T02:48:32+0900',
#     'regTimeGmt': '2023-04-16T17:48:32+0000',
#     'sympathyCount': 175,
#     'antipathyCount': 7,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '8ajYD',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'yclo****',
#     'maskedUserName': '요고****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '9',
#     'templateId': 'v2',
#     'commentNo': '14045028',
#     'parentCommentNo': '14045028',
#     'replyLevel': 1,
#     'replyCount': 2,
#     'replyAllCount': 2,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681662276432,
#     'contents': '혁명이니 뭐니 하며 없는 일까지 거짓 선동으로 누군가를 끌어내리는 일은 뭐 선한 일인가? 그보다 더한 악은 없을것 같은데. 역겹다.',
#     'userIdNo': '9mNUw',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '꽃토끼',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/28736/c856496c5c1779b13001ed818bc40b78d13a2a1b6b62a6d827dff7b4473a9243.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T01:24:36+0900',
#     'modTimeGmt': '2023-04-16T16:24:36+0000',
#     'regTime': '2023-04-17T01:24:36+0900',
#     'regTimeGmt': '2023-04-16T16:24:36+0000',
#     'sympathyCount': 159,
#     'antipathyCount': 17,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '9mNUw',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'ppop****',
#     'maskedUserName': '꽃토****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '5',
#     'templateId': 'v2',
#     'commentNo': '14045158',
#     'parentCommentNo': '14045158',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681663294494,
#     'contents': '하 이게 로맨스가 된다고..? 여주가 너무 불쌍해요',
#     'userIdNo': 'aC5Xp',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'Flowertomool',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/36447/1011f77605ece098ad42084262333d82dfb1daab8d9f97fcdcdc958bd19640ac.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T01:41:34+0900',
#     'modTimeGmt': '2023-04-16T16:41:34+0000',
#     'regTime': '2023-04-17T01:41:34+0900',
#     'regTimeGmt': '2023-04-16T16:41:34+0000',
#     'sympathyCount': 158,
#     'antipathyCount': 16,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'aC5Xp',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'hele****',
#     'maskedUserName': 'Fl****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '25',
#     'templateId': 'v2',
#     'commentNo': '14045236',
#     'parentCommentNo': '14045236',
#     'replyLevel': 1,
#     'replyCount': 2,
#     'replyAllCount': 2,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681664019452,
#     'contents': '아니지....너가 아네트를 떠날 수 없는거겠지..',
#     'userIdNo': '4gi5t',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '마임마이',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/16648/a1a0d86aaffc64c461590c8ff3eb975414d12bcc56e059bdb61dbc108f08d531.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T01:53:39+0900',
#     'modTimeGmt': '2023-04-16T16:53:39+0000',
#     'regTime': '2023-04-17T01:53:39+0900',
#     'regTimeGmt': '2023-04-16T16:53:39+0000',
#     'sympathyCount': 148,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '4gi5t',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'thdb****',
#     'maskedUserName': '마임****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '17',
#     'templateId': 'v2',
#     'commentNo': '14045630',
#     'parentCommentNo': '14045630',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681668240773,
#     'contents': '사람을 말려죽이네요. .너무 불쌍하다.작가님 너무 글 잘쓰시네요.여주 피폐한 맘 이 막 느껴져요',
#     'userIdNo': '2QHTO',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'ctke****',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/06412/704e2410e5a13e19e3010aadd3761fd23678822a44af079b4a9dee496105249e.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T03:04:01+0900',
#     'modTimeGmt': '2023-04-16T18:04:01+0000',
#     'regTime': '2023-04-17T03:04:01+0900',
#     'regTimeGmt': '2023-04-16T18:04:01+0000',
#     'sympathyCount': 144,
#     'antipathyCount': 13,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '2QHTO',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'ctke****',
#     'maskedUserName': 'ct****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '83',
#     'templateId': 'v2',
#     'commentNo': '14077254',
#     'parentCommentNo': '14077254',
#     'replyLevel': 1,
#     'replyCount': 3,
#     'replyAllCount': 3,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681916943294,
#     'contents': '하이너에겐 아네트는 전부였네요 하지만 아네트는 세상에 무지했고요\n아네트에겐 하이너는 사랑이었죠 하지만 하이너도 감정에 무지했고요',
#     'userIdNo': '3eL1z',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '하늘',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/07632/0ab708c9a496435e0df379d43314593be591e6b17fe96735d00681dfa2fff21e.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-20T00:09:03+0900',
#     'modTimeGmt': '2023-04-19T15:09:03+0000',
#     'regTime': '2023-04-20T00:09:03+0900',
#     'regTimeGmt': '2023-04-19T15:09:03+0000',
#     'sympathyCount': 140,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '3eL1z',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'jyyo****',
#     'maskedUserName': '하늘****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '7',
#     'templateId': 'v2',
#     'commentNo': '14046091',
#     'parentCommentNo': '14046091',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681678276041,
#     'contents': '헐 그래서 옷을 안벗고 했구나..이유가 있을 거 같긴한데 지금까지 마이너스999',
#     'userIdNo': '5fjFY',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '치즈된장치킨',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/07791/f30c010a8bbe46c7ccd714f725c61b627ba31138be73d0360709b31f4d1b0c46.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T05:51:16+0900',
#     'modTimeGmt': '2023-04-16T20:51:16+0000',
#     'regTime': '2023-04-17T05:51:16+0900',
#     'regTimeGmt': '2023-04-16T20:51:16+0000',
#     'sympathyCount': 138,
#     'antipathyCount': 15,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '5fjFY',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': '4blo****',
#     'maskedUserName': '치즈****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '11',
#     'templateId': 'v2',
#     'commentNo': '14045132',
#     'parentCommentNo': '14045132',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681663135823,
#     'contents': '웬지 먹먹하다~난 양쪽다 공감되서 그런가 웬지 먹먹하네 ㅜㅜㅜㅜ',
#     'userIdNo': 'wLvR',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'geoa****',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/31725/ec0b0a376b00e52c467327438072c86d83cf9f113e85fb78b3271d5868719e3e.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T01:38:56+0900',
#     'modTimeGmt': '2023-04-16T16:38:56+0000',
#     'regTime': '2023-04-17T01:38:56+0900',
#     'regTimeGmt': '2023-04-16T16:38:56+0000',
#     'sympathyCount': 131,
#     'antipathyCount': 6,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'wLvR',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'geoa****',
#     'maskedUserName': 'ge****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '7',
#     'templateId': 'v2',
#     'commentNo': '14045425',
#     'parentCommentNo': '14045425',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681665675781,
#     'contents': '왜 여주랑 불행배틀을 뜨려고 하는지...불행으로 비교를 하면 위아래 한도 끝도 없다. 사랑이든 증오든 하나만 선택해라',
#     'userIdNo': '2Z3SP',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'rrrr',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/45740/3989b72085d4574e7cf1337db19a20947c7f3b4faa0e6dd7c364d6bea02d1fe8.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T02:21:16+0900',
#     'modTimeGmt': '2023-04-16T17:21:16+0000',
#     'regTime': '2023-04-17T02:21:16+0900',
#     'regTimeGmt': '2023-04-16T17:21:16+0000',
#     'sympathyCount': 123,
#     'antipathyCount': 8,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '2Z3SP',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'fkag****',
#     'maskedUserName': 'rr****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '22',
#     'templateId': 'v2',
#     'commentNo': '14047304',
#     'parentCommentNo': '14047304',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681694807497,
#     'contents': '아네트도 제대로 된 재판없이 가족이 살해되었고…… 그래서 카트린을 이해한 건지도 모르겠네요. 접점 없는 두 삶이 겹친 지점이기도 하구요.\n또 카트린은 사과를 했으니까요. 저는 사과하는 아네트의 마음이 이해되네요.',
#     'userIdNo': 'yKHD',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '리리립',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/12931/961e2b26595a2679b15970262eb6d147072fe8ae082fcc41029ddda4a8662e1a.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T10:26:47+0900',
#     'modTimeGmt': '2023-04-17T01:26:47+0000',
#     'regTime': '2023-04-17T10:26:47+0900',
#     'regTimeGmt': '2023-04-17T01:26:47+0000',
#     'sympathyCount': 121,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'yKHD',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'dryn****',
#     'maskedUserName': '리리****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '43',
#     'templateId': 'v2',
#     'commentNo': '14047497',
#     'parentCommentNo': '14047497',
#     'replyLevel': 1,
#     'replyCount': 5,
#     'replyAllCount': 6,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681696517080,
#     'contents': '이슬만 먹고 살줄알았는데, 그게 참이슬이었구나~알았을때 그기분인가',
#     'userIdNo': 'wLvR',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'geoa****',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/31725/ec0b0a376b00e52c467327438072c86d83cf9f113e85fb78b3271d5868719e3e.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T10:55:17+0900',
#     'modTimeGmt': '2023-04-17T01:55:17+0000',
#     'regTime': '2023-04-17T10:55:17+0900',
#     'regTimeGmt': '2023-04-17T01:55:17+0000',
#     'sympathyCount': 118,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'wLvR',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'geoa****',
#     'maskedUserName': 'ge****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '51',
#     'templateId': 'v2',
#     'commentNo': '14052105',
#     'parentCommentNo': '14052105',
#     'replyLevel': 1,
#     'replyCount': 4,
#     'replyAllCount': 4,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681732211913,
#     'contents': '돈은…다주지말지…',
#     'userIdNo': '2jdYB',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '심심한뎁',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/07761/a5255d219c2775df075473f9386bc80c4698b8f76593c5eff9c4be9653062c17.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T20:50:12+0900',
#     'modTimeGmt': '2023-04-17T11:50:12+0000',
#     'regTime': '2023-04-17T20:50:12+0900',
#     'regTimeGmt': '2023-04-17T11:50:12+0000',
#     'sympathyCount': 112,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '2jdYB',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'qneo****',
#     'maskedUserName': '심심****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '4',
#     'templateId': 'v2',
#     'commentNo': '14046444',
#     'parentCommentNo': '14046444',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681685511182,
#     'contents': '사람들의 마음은 이해하지만 힘없는 여주에게 너무 치졸하게 군다.  혁명으로 일으킨 세력은 또다시 자기들이 혐오하는 그 세력이 되겠지',
#     'userIdNo': '6EbVP',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '시르페',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/02309/c0e5f4a5b5ac538dc3c8e532577086f4d6631367530efc0616edb8dd12c2de20.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T07:51:51+0900',
#     'modTimeGmt': '2023-04-16T22:51:51+0000',
#     'regTime': '2023-04-17T07:51:51+0900',
#     'regTimeGmt': '2023-04-16T22:51:51+0000',
#     'sympathyCount': 112,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '6EbVP',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'sire****',
#     'maskedUserName': '시르****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '22',
#     'templateId': 'v2',
#     'commentNo': '14047534',
#     'parentCommentNo': '14047534',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681696835278,
#     'contents': '카트린이 말한것처럼 제임스 버넷이 한건 약자를 향한 폭력이었고 아네트는 피해자지만, 사과를 하고 선처를 구한건 자신의 가족과 혈통, 그로인해 얻었던 물질적 풍요와 알려면 알수 있었음에도 당장의 평안에 시야를 가려버린 과거의 선택(무지)에 대한 책임을 조금이라도 지려고 하는거 같아요. 이번 사건을 통해 아네트 본인이 가진 피의 무게(정확히는 가족들의 죗값)를 체감하게된듯..',
#     'userIdNo': '3cEGj',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '코콩',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/19156/2685ef94caf072bd3ff96ca3c30d68e21cd1243787c3a6b875c1b08a8fc48b5c.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T11:00:35+0900',
#     'modTimeGmt': '2023-04-17T02:00:35+0000',
#     'regTime': '2023-04-17T11:00:35+0900',
#     'regTimeGmt': '2023-04-17T02:00:35+0000',
#     'sympathyCount': 111,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
# ...
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '버들이',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/49896/ca6261130264f74474193f2342c3c90c1bd5439349e314b22a678386b43cb6ea.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T10:50:09+0900',
#     'modTimeGmt': '2023-04-17T01:50:09+0000',
#     'regTime': '2023-04-17T10:50:09+0900',
#     'regTimeGmt': '2023-04-17T01:50:09+0000',
#     'sympathyCount': 101,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '3xCKT',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'sain****',
#     'maskedUserName': '버들****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '31',
#     'templateId': 'v2',
#     'commentNo': '14045639',
#     'parentCommentNo': '14045639',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681668409296,
#     'contents': '아네트가 안스가에게 가는게 아닌 스스로 치유할 수 있는 시간이 주어졌으면 좋겠어요..',
#     'userIdNo': 'aC5Xp',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'Flowertomool',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/36447/1011f77605ece098ad42084262333d82dfb1daab8d9f97fcdcdc958bd19640ac.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T03:06:49+0900',
#     'modTimeGmt': '2023-04-16T18:06:49+0000',
#     'regTime': '2023-04-17T03:06:49+0900',
#     'regTimeGmt': '2023-04-16T18:06:49+0000',
#     'sympathyCount': 98,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'aC5Xp',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'hele****',
#     'maskedUserName': 'Fl****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '20',
#     'templateId': 'v2',
#     'commentNo': '14048752',
#     'parentCommentNo': '14048752',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681707238654,
#     'contents': '여주가 꼭 남주를 벗어나길\n저시키 저거..\n이해해볼라다가도\n저런 자격지심을 가지고 사람 피말리는건\n꼬라지가 우스워 보여 안되겠음',
#     'userIdNo': 'mwY9',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '내포G뤼뽕',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/07086/41db4aae81301ad61f74a6296484ee6b14b589e6a1d030fbc6c6aa3ad6e20348.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-17T13:53:59+0900',
#     'modTimeGmt': '2023-04-17T04:53:59+0000',
#     'regTime': '2023-04-17T13:53:59+0900',
#     'regTimeGmt': '2023-04-17T04:53:59+0000',
#     'sympathyCount': 96,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': True,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': 'mwY9',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'wjsu****',
#     'maskedUserName': '내포****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '45',
#     'templateId': 'v2',
#     'commentNo': '14058312',
#     'parentCommentNo': '14058312',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681784196549,
#     'contents': '그런데 하이너가 가지는 여주에 대한 감정이 자격지심으로 인한 증오라고 끝내기엔 지금까지의 하이너의 삶이 너무 불쌍한데요...\n하이너의 감정이 하이너가 가질 수 있는 당연한 것 이라고 생각해요.\n카트린의 형제가 대의를 위함이 아니라 부당한 일을 당해서 혁명군에 있었던 것 처럼요. 하이너는 자신이 처한 상황이(세뇌에서 벗어남) 부당함을 주인공을 통해서 어느정도 깨닫게 됐고, 그래서 혁명에 몸 담았고...\n하이너가 느낀 바와같이 좋은 곳에서 태어났다면 마음 놓고 주인공을 사랑할 수 있었을 텐데. 그랬다면 양가적인 감정도 없었을테고 자신에 대한 확신을 배울 수 있었을 텐데.\n둘이 처한 상황이 안됐어요...얼른 행복해지길!!',
#     'userIdNo': '3va0f',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '반짝반짝반짝반짝반짝',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/28566/f62ba1cfd4561c4260d3e5b557a7d2874b7a63357d059f759695daffbdc96d23.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-18T11:16:37+0900',
#     'modTimeGmt': '2023-04-18T02:16:37+0000',
#     'regTime': '2023-04-18T11:16:37+0900',
#     'regTimeGmt': '2023-04-18T02:16:37+0000',
#     'sympathyCount': 94,
#     'antipathyCount': 5,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '3va0f',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'dudr****',
#     'maskedUserName': '반짝****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'series5',
#     'objectId': '504107_0',
#     'categoryId': '60',
#     'templateId': 'v2',
#     'commentNo': '14054520',
#     'parentCommentNo': '14054520',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1681745203759,
#     'contents': '너도 참 찌통서사지만 .. 아네트 입장에선 사랑하던 사람이 처음 접근부터 거짓이었다는데 뭘 해도 믿기겠냐규..ㅠ',
#     'userIdNo': '68UJm',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '목련꽃',
#     'userProfileImage': 'https://profile-phinf.pstatic.net/01082/c514b70e1b4a181d46721fb95cbf1861311ba5c45c69fd8b0294744ce944e25c.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-04-18T00:26:44+0900',
#     'modTimeGmt': '2023-04-17T15:26:44+0000',
#     'regTime': '2023-04-18T00:26:44+0900',
#     'regTimeGmt': '2023-04-17T15:26:44+0000',
#     'sympathyCount': 94,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': True,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': None,
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'manager': False,
#     'idNo': '68UJm',
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'maskedUserId': 'baek****',
#     'maskedUserName': '목련****',
#     'serviceId': None,
#     'userBlocked': False,
#     'exposeByCountry': False,
#     'profileUserId': None,
#     'blind': False,
#     'secret': False,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False}],
#   'userInfo': {},
#   'pageModel': {'page': 1,
#    'pageSize': 30,
#    'indexSize': 5,
#    'startRow': 1,
#    'endRow': 30,
#    'totalRows': 30,
#    'startIndex': 0,
#    'totalPages': 1,
#    'firstPage': 1,
#    'prevPage': 0,
#    'nextPage': 0,
#    'lastPage': 1,
#    'current': None,
#    'threshold': None,
#    'moveToLastPage': False,
#    'moveToComment': False,
#    'moveToLastPrev': False},
#   'morePage': {'prev': '00008p05zuimqe841in',
#    'next': '00002m05zvf4ksksfdm',
#    'start': '00008p05zuimqe841in',
#    'end': '00008p05zuimqe841in'},
#   'exposureConfig': {'reason': None, 'status': 'COMMENT_ON'},
#   'count': {'comment': 1747,
#    'reply': 227,
#    'exposeCount': 1749,
#    'delCommentByUser': 0,
#    'delCommentByMon': 0,
#    'blindCommentByUser': 0,
#    'blindReplyByUser': 0,
#    'total': 1974},
#   'sort': 'BEST',
#   'config': {'useSnsLogin': False,
#    'lineFeedOn': False,
#    'useBest': False,
#    'useVote': True,
#    'useVoteSelf': False,
#    'useVoteGoodOnly': False,
#    'useReport': True,
#    'useCommonReport': True,
#    'reportAuthority': 'ALL',
#    'useDeleteOnManagerReport': False,
#    'useReportSecret': False,
#    'useSort': True,
#    'sortTypes': ['BEST', 'ALL'],
#    'defaultSort': 'BEST',
#    'useByteLength': False,
#    'useReply': True,
#    'useReplyOnReply': False,
#    'pageAfterReply': 'TO_LAST_PAGE',
#    'maxReplyWriteBoxCount': 0,
#    'useAutoRefresh': False,
#    'useMention': False,
#    'min': 1,
#    'max': 500,
#    'useSticker': False,
#    'stickerOnly': False,
#    'stickerSupportedCategories': None,
#    'stickerDefaultCategory': None,
#    'stickerCategory': None,
#    'stickerContentsUrl': None,
#    'stickerKeyUrl': None,
#    'stickerTabUrl': None,
#    'stickerType': None,
#    'stickerText': False,
#    'stickerMarketUrl': None,
#    'stickerMobileResize': False,
#    'useProfile': False,
#    'useNaverProfile': False,
#    'dynamicProfile': False,
#    'profileImageAreas': ['LIST'],
#    'profileEmptyImage': None,
#    'displayMaskedUserId': True,
#    'useManager': False,
#    'managerDelete': False,
#    'managerBlock': False,
#    'managerNotice': False,
#    'contentsManagerIcon': False,
#    'secretComment': False,
#    'exposureConfig': False,
#    'deleteAllAfterBlock': False,
#    'useFold': True,
#    'replyPreviewCount': 0,
#    'maxImageUploadCount': 0,
#    'maxVideoUploadCount': 0,
#    'maxVideoImageUploadCount': 0,
#    'maxImageUploadFileSize': 0,
#    'imageAutoRotate': False,
#    'autoRefreshTime': 0,
#    'autoRefreshDefaultOff': False,
#    'autoRefreshChat': False,
#    'maxChatFPS': 0,
#    'commentModify': False,
#    'useCommentModify': False,
#    'useViewAll': True,
#    'useUserLevel': False,
#    'anyUseImageExpose': False,
#    'useImageComment': False,
#    'useVideoComment': False,
#    'useUrlLink': False,
#    'useCommentListIncludeDelete': True,
#    'useStats': False,
#    'statsMinCount': 0,
#    'useUserEnvStats': False,
#    'countryStatsMinCount': 0,
#    'useConcurrentStats': False,
#    'useVoteStats': False,
#    'useGpopCache': False,
#    'useEnterSubmit': False,
#    'useListReverse': False,
#    'useTranslation': False,
#    'useDeletedList': False,
#    'combinedDeletedList': False,
#    'displayDeletedList': False,
#    'applyChangedNotice': False,
#    'useUserCommentUi': False,
#    'useUserCommentProfileUi': False,
#    'userRecentStatsStartDate': None,
#    'userSortTypes': [],
#    'useMentionLegacyFormat': False,
#    'useMentionWrite': False,
#    'mentionMaxCount': 0,
#    'useSecret': False,
#    'useIdPenaltyLayer': False,
#    'useRestrictWriteBySns': False,
#    'photoInfraUploadDomain': None,
#    'photoInfraSelectDomainHttps': None,
#    'pcTempThumbnailType': 'ff80_80',
#    'mobileTempThumbnailType': 'ff50_50',
#    'realnameVerificationBlock': False,
#    'realnameVerificationMessage': None,
#    'useBlindByReport': False,
#    'keepTextareaOnRestriction': None,
#    'displayIndividualBlindOnly': False,
#    'hashtagMaxLength': 20,
#    'useDualPagination': False,
#    'reportReasonList': None,
#    'displayReportLayer': False,
#    'useHideAfterReport': False,
#    'useCleanbot': True,
#    'cleanbotEnforced': False,
#    'cleanbotServiceStepUI': 2,
#    'useCommentLinkToken': False,
#    'useUserBlock': True,
#    'useUserBlockNaverIdType': True,
#    'useUserBlockNeoIdType': False,
#    'useUserBlockProifleImageUi': True,
#    'useChoice': False,
#    'useNcc': False,
#    'useRating': False,
#    'ratingUseSingleType': False,
#    'ratingScale': 0,
#    'ratingSelectorCount': 0,
#    'useFollow': False,
#    'useManagerLike': False,
#    'usePick': False,
#    'pickLimit': 0,
#    'pickManagerLimit': 0,
#    'useReference': False,
#    'useLMP': False,
#    'pageType': None,
#    'pageSize': 0,
#    'indexSize': 0,
#    'userCommentPageSize': 0,
#    'userCommentReplyPageSize': 0,
#    'replyPageSize': 0,
#    'replyIndexSize': 0,
#    'feedPageSize': 0,
#    'blindReportReasonList': None},
#   'bestList': []},
#  'date': '2023-05-01T06:46:44+0000'}

# %%
len(dict_data['result']['commentList'])
# Out:
# 30
