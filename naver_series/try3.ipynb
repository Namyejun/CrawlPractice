# %%
NAVER_SERIES_DETAIL_URL = "https://series.naver.com/novel/detail.series?productNo=9654104"

# %%
import requests
from fake_useragent import UserAgent
from bs4 import BeautifulSoup as BS
import re
import pandas as pd
import threading
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
headers={'User-Agent':'Mozilla/5.0'}
response=requests.get(NAVER_SERIES_DETAIL_URL, headers=headers)
html_code = response.content

# %%
soup = BS(html_code, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="No-Cache" http-equiv="Cache-Control"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <title>네이버 시리즈</title>
# <link href="https://ssl.pstatic.net/static/nstore/series_favicon_152.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static/nstore/series_favicon_114.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static/nstore/series_favicon_114.png" rel="apple-touch-icon-precomposed" sizes="114X114"/>
# <link href="https://ssl.pstatic.net/static/nstore/series_favicon_120.png" rel="apple-touch-icon-precomposed" sizes="120X120"/>
# <link href="https://ssl.pstatic.net/static/nstore/series_favicon_144.png" rel="apple-touch-icon-precomposed" sizes="144X144"/>
# <link href="https://ssl.pstatic.net/static/nstore/series_favicon_152.png" rel="apple-touch-icon-precomposed" sizes="152X152"/>
# <link href="/css/nstore_util.css?1680572756000" rel="stylesheet" type="text/css"/>
# <link href="/css/nstore_cont.css?1677051170000" rel="stylesheet" type="text/css"/>
# <link href="/css/skip/nstore_js.css?1677051170000" rel="stylesheet" type="text/css"/>
# <link href="/css/nstore.css?1677051170000" rel="stylesheet" type="text/css"/>
# <link href="/css/likeit_nstore.css?1677051170000" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#
# var gnb_service = "nstore";
# var gnb_logout = encodeURIComponent(location.href);
# var gnb_template = "gnb_utf8";
# var gnb_brightness = 1;
#
#
#
# var LOGIN_STATUS = {
# 	"LOGIN" : 0,
# 	"LOGOUT" : 1,
# 	"UNKNOWN" : 2
# };
#
# var ID_TYPE_STATUS = {
# 		"PERSONAL" : 0,
# 		"PRIVATELY_OWNED_BUSINESS" : 1,
# 		"PROFIT_CORPORATION" : 2,
# 		"NONPROFIT_CORPORATION" : 3,
# 		"ETC" : 4
# };
#
# var gIsGroupId = false;
#
# var gLoginStatus;
# if (false == true) {
# 	gLoginStatus = LOGIN_STATUS.LOGIN;
# } else if (false == false) {
# 	gLoginStatus = LOGIN_STATUS.LOGOUT;
# } else {
# 	gLoginStatus = LOGIN_STATUS.UNKNOWN;
# }
#
# var gIsGroupId = false;
# if (false == true && true) {
# 	gIsGroupId = true;
# }
#
#
# var gIsRealName = false;
# if (false == true && false) {
# 	gIsRealName = true;
# }
#
#
# var logoutCurrentFullUrl = "";
# var loginCurrentFullUrl = "";
#
#
# var ccsrv = "cc.naver.com";
# var nsc = "nstore";
# var nclk_evt = 3;
#
#
# var lcs_SerName = "lcs.naver.com";
#
#
# var gRosYn = 'N';
# var gRosAlertMessage = '서비스 점검 중입니다.\n\n점검시간: 8월 4일 02시~07시(5시간)\n\n네이버페이 DB점검 작업으로 서비스 이용이\n불가능합니다. 이용에 불편을 드려 죄송합니다.';
#
#
# var gInspYn = 'Y';
#
# var gsDenyGroupIdMessage = "단체 아이디로 로그인하면 이용할 수 없습니다. 일반 아이디로 로그인 후 다시 이용해 주세요.";
# </script>
# <script>
# 	if (window.location.pathname.indexOf("/my") === 0) {
# 		var g_ssc = "series.my";
# 	} else {
# 		var g_ssc = "series.novel";
# 	}
# 	var ccsrv = "cc.naver.com";
# 	window.nsc = g_ssc;
# </script>
# <script src="/js/nclk.js"></script>
# <script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-140047759-2"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('set', {'user_id': ''});
#     gtag('config', 'UA-140047759-2');
# </script>
# <meta content="/WEB-INF/jsp/comicnovel/detailScript.jsp" name="jsfooter">
# <meta content="4회차는 명전이다" property="og:title">
# <meta content="article" property="og:type">
# <meta content="https://series.naver.com/novel/detail.series?productNo=9654104" property="og:url"/>
# <meta content="https://comicthumb-phinf.pstatic.net/20230414_75/pocket_1681449546209HqVqD_JPEG/00004%C8%B8%C2%F7%B4%C2%B8%ED%C0%FC%C0%CC%B4%D9_%C5%B8%C0%CC%C6%F7%C3%D6%C1%BE.jpg?type=m600x314" property="og:image"/>
# <meta content="첫 턴 명예의 전당 입성, 야구선수로서 최고의 명예.
#
# 그러나 라이벌에게 밀려 실패한 3회차.
#
# 이번 4회차에는 압도적인 성적으로 달성하겠다." property="og:description"/>
# <meta content="북스토어 | 웹소설 | 네이버 시리즈" property="og:article:author"/>
# <script type="text/javascript">
#         var nsc = "series.novel";
# 		var g_ssc = "series.novel";
# 	</script>
# </meta></meta></meta></meta></head>
# <body class="bs">
# <a class="skip" href="#top_menu" onclick="document.getElementById('top_menu').tabIndex=-1;document.getElementById('top_menu').focus();return false;">메인메뉴 바로가기</a>
# <a class="skip" href="#container" onclick="document.getElementById('container').tabIndex=-1;document.getElementById('container').focus();return false;">본문 바로가기</a>
# <div class="end" id="wrap">
# <!-- header -->
# <div id="header_series">
# <div class="series" id="header">
# <div class="nstore_gnb_wrap">
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2023042914" type="text/javascript"></script>
# </div>
# </div>
# <!-- LNB -->
# <div class="main_box">
# <h1>
# <a class="naver" href="http://www.naver.com/">NAVER</a>
# <a class="main_series N=a:STA.nstore" href="/nstoreHome.series">시리즈</a>
# </h1>
# <div class="gnb"></div>
# </div>
# <!-- LNB -->
# <div class="tab_box">
# <div class="tab_box_wrap">
# <h2 class="blind">Local Navigation Bar</h2>
# <ul class="lnb NE=a:LNB" id="top_menu">
# <li class="lnb_list list_no on"><a class="no N=a:LNB.novel" href="/novel/home.series"><span class="blind">웹소설</span></a>
# <ul class="list_inner NE=a:snb">
# <li class="">
# <a class="no1 NPI=a:home" href="/novel/home.series"><span class="blind">웹소설 홈</span></a>
# </li>
# <li class="">
# <a class="cm2 NPI=a:category" href="/novel/recommendList.series"><span class="blind">카테고리</span></a>
# </li>
# <li class="">
# <a class="cm10 NPI=a:top" href="/novel/top100List.series"><span class="blind">TOP 100</span></a>
# </li>
# <li class="">
# <a class="cm15 NPI=a:freepass" href="/novel/specialFreeList.series?specialFreeTypeCode=HOURLYFREE"><span class="blind">프리패스</span></a>
# </li>
# <li class="">
# <a class="cm14 NPI=a:free" href="/novel/specialFreeList.series?specialFreeTypeCode=FREEFROMTODAY"><span class="blind">매일10시무료</span></a>
# </li>
# <li class="">
# <a class="cm4 NPI=a:event" href="/novel/specialFreeList.series?specialFreeTypeCode=TIMEDEAL"><span class="blind">타임딜</span></a>
# </li>
# </ul>
# <div class="noble_recommend_box">
# <h3 class="noble_recommend_txt">추천장르</h3>
# <ul class="noble_recommend">
# <li>
# <a class="no_sub1" href="/novel/categoryProductList.series?categoryTypeCode=genre&amp;genreCode=201" target="_self">로맨스</a>
# </li>
# <li>
# <a class="no_sub2" href="/novel/categoryProductList.series?categoryTypeCode=genre&amp;genreCode=207" target="_self">로판</a>
# </li>
# <li>
# <a class="no_sub3" href="/novel/categoryProductList.series?categoryTypeCode=genre&amp;genreCode=202" target="_self">판타지</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lnb_list list_cm"><a class="cm NPI=a:comic" href="/comic/home.series"><span class="blind">만화</span></a>
# </li>
# <li class="lnb_list list_bs type_bar"><a class="bs NPI=a:ebook" href="/ebook/home.series"><span class="blind">e북</span></a>
# </li>
# <li class="lnb_list list_etc_serieson">
# <a class="" href="https://serieson.naver.com/v2/movie" onclick="nclk_v2(event, 'lnb.serieson', '', '');"><span class="blind">영화·방송</span></a>
# </li>
# </ul>
# <!-- MCMS 공지사항 부분 -->
# <div class="my_info_box">
# <ol class="my_info">
# <li><a class="N=a:STA.my" href="/my/library/productList.series"><span class="my_cart">MY보관함</span></a></li>
# <li>
# <a href="/cart/list.series"><span class="my_shopbox">장바구니</span>
# <span class="txt" id="cartCountArea">0</span>
# </a>
# </li>
# </ol>
# <!-- 자동완성 검색 기능 -->
# <div class="srch" id="acfield">
# <form action="/search/search.series" id="ac_form1" method="get" onsubmit="">
# <fieldset class="g_window">
# <legend>검색</legend>
# <div class="gbox">
# <span>
# <input id="acSection" type="hidden" value="all_"/>
# <input name="t" type="hidden" value="all"/>
# <input name="fs" type="hidden" value="novel"/>
# <input autocomplete="off" class="txt" id="ac_input1" name="q" onblur="$Element($$.getSingle('#acfield')).removeClass('on');" onfocus="$Element($$.getSingle('#acfield')).addClass('on');" placeholder="작품명, 작가명을 입력하세요." title="검색입력폼" type="text" value=""/>
# </span>
# </div>
# <!-- 텍스트 클리어 버튼 -->
# <a class="btn_text_clear" id="clearAcSection" style="display: none"><span class="blind">텍스트 삭제</span></a>
# <!-- //텍스트 클리어 버튼 -->
# <!-- 화살표 버튼 -->
# <a class="btn_search arrow_down" href="#" id="ac_button1"><span class="blind">검색 창 닫기</span></a>
# <!-- 검색버튼 -->
# <button class="btn_smt N=a:STA.sch" type="submit">검색</button>
# <!-- View - 일반태그 -->
# <div class="ly_atcmp" id="ac_view1" style="width:268px;background-color: rgb(255, 255, 255);border-right: 1px solid #ddd;border-bottom: 1px solid #ddd;border-left: 1px solid #ddd;border-image: initial;border-top: none;display: none;">
# <div class="words">
# <ul class="_resultBox">
# <li class="@url_class@"><a href="#" onclick="clickcr(this, 'acl.kw', '', '', event); return false;" title="">@txt@</a><a class="mquick" href="@url@" target="_blank">바로가기</a><span id="rank@rank@" style="display:none">@in_txt@</span></li>
# </ul>
# </div>
# <div class="help" style="width:258px;"><a class="N=a:acl.off" href="javascript:setDisableAC();">자동완성 끄기</a></div>
# </div>
# <div class="ly_atcmp" id="acIng" style="width:258px; background-color:#fff;border:1px solid #ddd;border-top:none;display:none;">
# <div class="words">
# <ul class="_resultBox">
# <li class="@url_class@"><a>현재 자동완성을 사용하고 계십니다.</a></li>
# </ul>
# </div>
# <div class="help" style="width:258px;"><a class="N=a:acl.off" href="javascript:setDisableAC();">자동완성 끄기</a></div>
# </div>
# <div class="ly_atcmp" id="acSet" style="width:258px; background-color:#fff;border:1px solid #ddd;border-top:none;display:none;">
# <div class="words">
# <ul class="_resultBox">
# <li class="@url_class@"><a>자동완성 기능이 활성화 되었습니다.</a></li>
# </ul>
# </div>
# <div class="help" style="width:258px;"><a class="N=a:acl.off" href="javascript:setDisableAC();">자동완성 끄기</a></div>
# </div>
# </fieldset>
# </form>
# </div>
# <!-- //자동완성 검색 기능 -->
# </div>
# </div>
# </div>
# <!-- 쿠폰 배너 노출을 위한 layer -->
# <div class="ly_banner" id="couponBannerLayer" style="display:none">
# </div>
# <div class="gra_top"></div>
# </div>
# </div>
# <!-- LNB -->
# <!-- //header -->
# <hr/>
# <!-- container -->
# <div class="end" id="container">
# <div class="aside NE=a:nvi">
# <span class="pic_area">
# <span class="mask"></span>
# <img alt="4회차는 명전이다" height="260" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_173x260.gif'" src="https://comicthumb-phinf.pstatic.net/20230414_75/pocket_1681449546209HqVqD_JPEG/00004%C8%B8%C2%F7%B4%C2%B8%ED%C0%FC%C0%CC%B4%D9_%C5%B8%C0%CC%C6%F7%C3%D6%C1%BE.jpg?type=m260" width="173"/>
# </span>
# <div class="myuseinfo">
# <h3 class="rnd_h"><span class="rnd"><span class="spr_cookies_img tit_my_save_cookies">보유 중인 쿠키</span></span></h3>
# <!-- [D] 비로그인 -->
# <div class="info_cash" id="no_login">
# <div class="info_cash_text">
# <p class="login_text">쿠키 수를 확인해주세요.</p>
# </div>
# <a class="cash_charge" href="https://nid.naver.com/nidlogin.login" onclick="nclk_v2(event, 'info.login');">로그인</a>
# </div>
# </div>
# <ul class="aside_info">
# <li>
# <h4 class="tit tit_eq">지원기기</h4>
# <p><span class="ico ico_pc2"></span>PC <span class="ico ico_hp"></span>모바일 5대</p>
# <p>PC의 경우, Windows OS에서만 <br/>구매/대여 및 재생 가능합니다.</p>
# </li>
# <li>
# <h4 class="tit tit_useinfo">이용정보</h4>
# <p class="ebook_txt v1">종이책이 아닌 eBook 상품으로<br/>PC, 모바일에서 볼 수 있습니다.</p>
# <a class="lk_ruleguide" href="#" onclick="openVoucherNotice('novel'); nclk_v2(event, 'info.howto'); return false;" target="_blank">이용방법 안내<em class="ico"></em></a>
# </li>
# <li>
# <h4 class="tit tit_rfndinfo">환불안내</h4>
# <p class="ebook_txt">구매 후 7일 이내에 열람하지 않은 회차는 <a class="rf_link" href="/my/purchase/purchasedProductList.series">MY보관함&gt;구입내역</a>에서 구매 취소할 수 있습니다.</p>
# <p class="ebook_txt">단, 유효기간 만료된 쿠키나 이용권은 제외되고 환불됩니다.</p>
# <p class="ebook_txt">뷰어가 설치되어 있는 경우, 구매와 동시에 열람될 수 있으니 유의 바랍니다.</p>
# <a class="lk_ruleguide" href="#" onclick="openContractInfo(); nclk_v2(event, 'info.rule'); return false;" target="_blank">규정안내<em class="ico"></em></a>
# <a class="lk_ruleguide" href="#" onclick="openPassContractInfo(); nclk_v2(event, 'info.cookierule'); return false;" target="_blank">쿠키이용약관<em class="ico"></em></a>
# </li>
# </ul>
# <div class="aside_air" id="genrePopularProductRollingArea">
# <h3><span class="tit tit_hitnovel">이 장르의 인기 웹소설</span></h3>
# </div>
# <div class="aside_air">
# <h3><span class="tit tit_top10novel">웹소설 TOP10</span></h3>
# <!-- 리스트 -->
# <ul class="aside_top10">
# <li>
# <span class="ico_top t1">1</span>
# <strong>
# <a href="/novel/detail.series?productNo=9678957" onclick="nclk_v2(event, 'frk.list', '9678957', '1');" title="살 빼고 다 바뀌었습니다 [선공개]">살 빼고 다 바뀌었습니다 [선공개]</a>
# </strong>
# <em><span class="author">네코다메론</span></em>
# </li>
# <li>
# <span class="ico_top t2">2</span>
# <strong>
# <a href="/novel/detail.series?productNo=9675584" onclick="nclk_v2(event, 'frk.list', '9675584', '2');" title="오직 울게 하소서">오직 울게 하소서</a>
# </strong>
# <em><span class="author">두루딱</span></em>
# </li>
# <li>
# <span class="ico_top t3">3</span>
# <strong>
# <a href="/novel/detail.series?productNo=6037518" onclick="nclk_v2(event, 'frk.list', '6037518', '3');" title="게임 속 바바리안으로 살아남기 [독점]">게임 속 바바리안으로 살아남기 [독점]</a>
# </strong>
# <em><span class="author">정윤강</span></em>
# </li>
# <li>
# <span class="ico_top t4">4</span>
# <strong>
# <a href="/novel/detail.series?productNo=4130558" onclick="nclk_v2(event, 'frk.list', '4130558', '4');" title="화산귀환 [독점]">화산귀환 [독점]</a>
# </strong>
# <em><span class="author">비가</span></em>
# </li>
# <li>
# <span class="ico_top t5">5</span>
# <strong>
# <a href="/novel/detail.series?productNo=9679423" onclick="nclk_v2(event, 'frk.list', '9679423', '5');" title="빈틈없이 네 안으로 [선공개]">빈틈없이 네 안으로 [선공개]</a>
# </strong>
# <em><span class="author">빵곰탕</span></em>
# </li>
# <li>
# <span class="ico_top t6">6</span>
# <strong>
# <a href="/novel/detail.series?productNo=9653969" onclick="nclk_v2(event, 'frk.list', '9653969', '6');" title="당가암룡">당가암룡</a>
# </strong>
# <em><span class="author">처량한날</span></em>
# </li>
# <li>
# <span class="ico_top t7">7</span>
# <strong>
# <a href="/novel/detail.series?productNo=9684004" onclick="nclk_v2(event, 'frk.list', '9684004', '7');" title="대표님과 나쁜 짓">대표님과 나쁜 짓</a>
# </strong>
# <em><span class="author">잎새달</span></em>
# </li>
# <li>
# <span class="ico_top t8">8</span>
# <strong>
# <a href="/novel/detail.series?productNo=9614687" onclick="nclk_v2(event, 'frk.list', '9614687', '8');" title="문샤크: 그 공주가 데뷔하는 법">문샤크: 그 공주가 데뷔하는 법</a>
# </strong>
# <em><span class="author">번들</span></em>
# </li>
# <li>
# <span class="ico_top t9">9</span>
# <strong>
# <a href="/novel/detail.series?productNo=8714962" onclick="nclk_v2(event, 'frk.list', '8714962', '9');" title="공작과 미스터리를 쓰는 밤 [독점]">공작과 미스터리를 쓰는 밤 [독점]</a>
# </strong>
# <em><span class="author">젤린</span></em>
# </li>
# <li>
# <span class="ico_top t10">10</span>
# <strong>
# <a href="/novel/detail.series?productNo=8126058" onclick="nclk_v2(event, 'frk.list', '8126058', '10');" title="플레이어가 과거를 숨김 [독점]">플레이어가 과거를 숨김 [독점]</a>
# </strong>
# <em><span class="author">베데스</span></em>
# </li>
# </ul>
# <!-- //리스트 -->
# <p class="more_area"><a class="lk_more" href="/novel/top100List.series" onclick="nclk_v2(event, 'frk.more');"><span class="blind">웹소설 TOP10</span>더보기<em class="ico"></em></a></p>
# </div>
# <!-- 이용안내 가이드 -->
# <ul class="aside_guide">
# <li><a class="lk_guide" href="/guide/userGuide.series" onclick="nclk_v2(event, 'info.aboutseries');">시리즈 활용백서 - 한번의 결제로 모바일폰, 탭즐릿, PC까지 어디서나</a></li>
# <li><a class="lk_app" href="/series" onclick="nclk_v2(event, 'info.seriesapp');" target="_blank">시리즈앱 웹툰부터 웹소설까지 시리즈로 달린다.</a></li>
# </ul>
# <!-- //이용안내 가이드 -->
# </div>
# <div id="content">
# <div class="end_head">
# <h2>4회차는 명전이다</h2>
# <div class="score_area"><span class="score"><span style="width:69.00000095367432%">평점</span></span><em>6.9</em></div>
# <div class="user_action_area">
# <ul>
# <li class="FavoriteProductManager.addFavoriteProduct(2,9654104,on,) NPI=a:fav" id="productFavorite">
# <a class="btn_interest" href="#">관심</a></li>
# <li>
# <div class="u_likeit_module"></div>
# </li>
# <li>
# <a class="btn_comment" data-option="{baseElement:'spiButton2', layerPosition:'outside-bottom', align:'left', top:4, left:0, marginLeft:8, marginTop:10}" href="#cbox_module" onclick="location.href='#cbox_module'; nclk_v2(event, 'end.comment')">
# <span id="reviewCount">0</span>
# </a>
# </li>
# <li>
# <a class="btn_share naver-splugin" data-me-oninitialize="onSubscribe(this);" data-option="{baseElement:'spiButton2', layerPosition:'outside-bottom', align:'left', top:4, left:0, marginLeft:8, marginTop:10}" data-style="unity-v2" data-url="https://series.naver.com/novel/detail.series?productNo=9654104" href="#" id="spiButton2"><span>공유</span></a>
# </li>
# </ul>
# </div>
# </div>
# <ul class="end_info NE=a:nvi">
# <li class="info_lst">
# <ul>
# <li class="ing"><span>연재중</span></li>
# <li><span><a href="/novel/categoryProductList.series?categoryTypeCode=genre&amp;genreCode=208">현판</a></span></li>
# <li><span>글</span><a href="/search/search.series?t=all&amp;fs=novel&amp;q=%EC%A0%95%EC%82%AC%EB%B6%80">정사부</a></li>
# <li><span>출판사</span><a href="/search/search.series?t=all&amp;fs=novel&amp;q=%EB%BF%94%EB%AF%B8%EB%94%94%EC%96%B4">뿔미디어</a></li>
# <li>전체 이용가</li>
# </ul>
# </li>
# </ul>
# <div class="end_dsc">
# <div class="_synopsis">첫 턴 명예의 전당 입성, 야구선수로서 최고의 명예.
# ..
#
# <span class="al_r"><a class="lk_more _toggleMore(synopsis)" href="#" onclick="nclk_v2(event, 'end.storemore', '9654104');">더보기<em></em></a></span>
# </div>
# <div class="_synopsis" style="display: none">
# 							첫 턴 명예의 전당 입성, 야구선수로서 최고의 명예.
# <br> <br>그러나 라이벌에게 밀려 실패한 3회차.
# <br/> <br/>이번 4회차에는 압도적인 성적으로 달성하겠다.
# 						<span class="al_r"><a class="lk_more up _toggleMore(synopsis)" href="#" onclick="nclk_v2(event, 'end.storeclose', '9654104');">접기<em></em></a></span>
# </br></br></div>
# </div>
# <!-- 앤드링크 -->
# <!--//앤드링크 -->
# <!-- 공지사항 & event -->
# <ul class="end_evt NE=a:nvi">
# </ul>
# <!-- //event -->
# <div class="end_title_fixed_price_sign NE=a:nvi">
# <div class="area_card">
# <div class="area_text_information"><span class="tit tit_priceinfo">가격정보</span>
# <strong>25화</strong>
#                 무료
#
#         </div>
# <div class="area_fixed_price_sign _togglePriceInfoLayer">
# <a class="this_icon_help" href="#" onclick="nclk_v2(event, 'end.price', '9654104');"><span class="blind">가격정보 도움말</span></a>
# <div class="area_layer_wrap" id="priceInfo" style="display:none;">
# <!-- [D] 레이어팝업 닫기 및 오픈 시 display:none block 처리 해주세요. style 속성은 마크업 확인을 위한 임시코드이니 개발 시 삭제해 주세요. -->
# <!-- [D] 레이어팝업 케이스1 -->
# <div class="area_text_box">
# <dl class="dlist">
# <div class="area_card">
# <dd><span>100</span>원</dd>
# </div>
# </dl>
# <p class="area_text_sub">*상기 가격은 도서의 정가이며, 도서의 실제 대여/소장 가격<br/>은 쿠키의 구매처에 따라 이와 달라질 수 있습니다.</p>
# </div>
# <!-- // -->
# <a class="area_button_cancle _togglePriceInfoLayer" href="#"><span class="this_text"><span class="blind">가격정보 도움말 닫기</span></span></a>
# </div>
# </div>
# </div>
# </div>
# <!-- [D] 가격 정보 케이스2 -->
# <div class="area_ebook_price_information">
# <div class="area_card">
# <dl class="area_card_inner">
# <dt class="area_title">
# <strong>소장</strong>
# </dt>
# <dd class="area_description">
# <div class="area_description_inner">
# <div class="area_price">
# <span>쿠키 <span class="point_color">1</span>개</span>
# </div>
# <div class="area_period">소장</div>
# </div>
# </dd>
# </dl>
# </div>
# </div>
# <div class="end_my_overview">
# <span class="my_use"><em>시리즈</em> 앱을 이용하시면 더 많은 혜택이 있어요!</span><a href="/series" onclick="nclk_v2(event, 'end.sapp', '9654104');" target="_blank">자세히 보기</a>
# </div>
# <!-- 대여 / 구매 -->
# <h5 class="end_total_episode">
#     총 <strong>141</strong>화
#
# </h5>
# <table border="1" cellspacing="0" class="tbl_buy_head v2" summary="최신순으로보기,1화부터보기,미리보기.관심설정,회차보기">
# <caption>대여/구매 테이블</caption>
# <colgroup>
# <col style="width:73px"/><col style="width:535px"/><col style="width:57px"/><col/>
# </colgroup>
# <thead>
# <tr>
# <!-- [D] 활성화 시 div에 class="on" 추가해주세요-->
# <th class="chk" scope="col"><div class="_changeTicketSortOrder(DESC)" onclick="nclk_v2(event, 'lst.recent');"><button class="txt" type="button">최신순</button></div></th>
# <!-- [D] 활성화 시 div에 class="on" 추가해주세요-->
# <th class="firstview v2" scope="col">
# <div class="on _changeTicketSortOrder(ASC)" onclick="nclk_v2(event, 'lst.seq');">
# <button class="txt" type="button">1화부터보기</button>
# </div>
# </th>
# <th scope="col"><span class="tit tit_preview2">미리보기</span></th>
# <th class="buy" scope="col">
# </th></tr>
# </thead>
# <tbody><tr><td colspan="6"></td></tr></tbody>
# </table>
# <div class="loading_wrap" id="loadingBar" style="display: none">
# <div class="loading"><img alt="로딩중" height="28" src="https://ssl.pstatic.net/static/nstore/loading_white.gif" width="210"/></div>
# </div>
# <div class="cont_list_box">
# <div style="width:782px">
# <div class="tbl_buy_wrap">
# <div class="nodata" id="noVolumeData" style="display: none">목록 정보를 가져올 수 없습니다.</div>
# <table border="1" class="tbl_buy" summary="대여/구매 테이블 리스트">
# <caption>대여/구매 테이블 리스트</caption>
# <colgroup>
# <col style="width:20px"/><col style="width:590px"/><col style="width:60px"/><col/>
# </colgroup>
# <tbody id="volumeList"></tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="pagenate2 NE=a:nvx" id="volumeListPagenate"></div>
# <!-- //대여 / 구매 -->
# <div class="end_tit v2" id="_otherProductByPerson"><strong class="part">작가</strong><strong>정사부</strong><span class="tit tit_othernovel_v2">의 다른 웹소설</span></div>
# <div class="also_wrap v2 NE=a:nvw">
# <div class="flick_view_area">
# <div class="flick_container" style="width:10000px">
# <!-- 리스트 -->
# <ul class="lst_thum flick_ct">
# <li class="book">
# <a class="NPI=a:list,r:1,i:9624463" href="/novel/detail.series?productNo=9624463" title="울트라 코리아">
# <span class="mask"></span>
# <img alt="울트라 코리아" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20230407_275/pocket_1680833730390sEeNN_JPEG/0000%BF%EF%C6%AE%B6%F3%C4%DA%B8%AE%BE%C6-%C0%CC%BA%CF%BF%EB%C7%A5%C1%F6.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>울트라 코리아</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:2,i:5563856" href="/novel/detail.series?productNo=5563856" title="헌터 레볼루션 [단행본]">
# <span class="mask"></span>
# <img alt="헌터 레볼루션 [단행본]" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20201008_261/pocket_1602118500136DPfmq_JPEG/__15%28%29.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>헌터 레볼루션 [단행본]</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:3,i:5492198" href="/novel/detail.series?productNo=5492198" title="베스트 오브 베스트">
# <span class="mask"></span>
# <img alt="베스트 오브 베스트" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20200911_6/pocket_1599812221343n6Wr5_JPEG/___.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>베스트 오브 베스트</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:4,i:5477542" href="/novel/detail.series?productNo=5477542" title="매직 코리아">
# <span class="mask"></span>
# <img alt="매직 코리아" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20200907_120/pocket_1599462486494jEvI2_JPEG/__.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>매직 코리아</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:5,i:5340127" href="/novel/detail.series?productNo=5340127" title="가디언 더 하이브리드">
# <span class="mask"></span>
# <img alt="가디언 더 하이브리드" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20200724_218/pocket_1595581988766p0ay0_JPEG/___.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>가디언 더 하이브리드</strong>
# </a>
# </li>
# </ul>
# <ul class="lst_thum flick_ct">
# <li class="book">
# <a class="NPI=a:list,r:6,i:4133088" href="/novel/detail.series?productNo=4133088" title="스타 라이프 [단행본]">
# <span class="mask"></span>
# <img alt="스타 라이프 [단행본]" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20190424_126/pocket_1556082323968TM9yV_JPEG/_2.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>스타 라이프 [단행본]</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:7,i:3106058" href="/novel/detail.series?productNo=3106058" title="헌팅 프론티어 [단행본]">
# <span class="mask"></span>
# <img alt="헌팅 프론티어 [단행본]" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20171127_279/pocket_1511754028089fxXpW_JPEG/image_H1_%281%29.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>헌팅 프론티어 [단행본]</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:8,i:2330400" href="/novel/detail.series?productNo=2330400" title="그레이트 코리아 [단행본]">
# <span class="mask"></span>
# <img alt="그레이트 코리아 [단행본]" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20160610_246/pocket_1465540721567YVIkM_JPEG/-14-.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>그레이트 코리아 [단행본]</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:9,i:1732443" href="/novel/detail.series?productNo=1732443" title="코리아 갓파더 [단행본]">
# <span class="mask"></span>
# <img alt="코리아 갓파더 [단행본]" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20150202_87/pocket_1422865913950blVck_JPEG/150102776.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>코리아 갓파더 [단행본]</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:10,i:1389732" href="/novel/detail.series?productNo=1389732" title="베스트 오브 베스트 [단행본]">
# <span class="mask"></span>
# <img alt="베스트 오브 베스트 [단행본]" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20140224_213/pocket_1393206835765CPbv9_JPEG/140228743.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>베스트 오브 베스트 [단행본]</strong>
# </a>
# </li>
# </ul>
# <ul class="lst_thum flick_ct">
# <li class="book">
# <a class="NPI=a:list,r:11,i:641010" href="/novel/detail.series?productNo=641010" title="가디언 더 하이브리드 [단행본]">
# <span class="mask"></span>
# <img alt="가디언 더 하이브리드 [단행본]" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20130513_72/pocket_1368432063502KVN9F_JPEG/130401576.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>가디언 더 하이브리드 [단행..</strong>
# </a>
# </li>
# <li class="book">
# <a class="NPI=a:list,r:12,i:480852" href="/novel/detail.series?productNo=480852" title="매직 코리아 [단행본]">
# <span class="mask"></span>
# <img alt="매직 코리아 [단행본]" class="lazyImg" data-original="https://comicthumb-phinf.pstatic.net/20120914_228/pocket_1347587005876NWI68_JPEG/120900669.jpg?type=m101" height="152" onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_101x152.gif'" width="101"/>
# <strong>매직 코리아 [단행본]</strong>
# </a>
# </li>
# </ul>
# <!-- 리스트 -->
# </div>
# </div>
# <!-- 이전,다음 -->
# <div class="scroll_area">
# <a class="prev CircularRollingManager.moveBy(-1) NPI=a:prev" href="#"><em>작가 정사부의 다른 웹소설 이전페이지</em></a>
# <span class="flick_ico">
# <!-- [D] 선택된것은 strong태그로 변경 -->
# <strong>1</strong>
# <a class="CircularRollingManager.moveTo(2) N=a:nvw.page,r:2" href="#">2</a>
# <a class="CircularRollingManager.moveTo(3) N=a:nvw.page,r:3" href="#">3</a>
# </span>
# <a class="next CircularRollingManager.moveBy(1) NPI=a:next" href="#"><em>작가 정사부의 다른 웹소설 다음페이지</em></a>
# </div>
# <!-- 이전,다음 -->
# </div>
# <div class="u_cbox series_comment_section" id="cbox_module"></div>
# <!-- //함께 구매된 상품 -->
# </div>
# </div>
# <!-- //container -->
# <div class="tost_pop" id="cookieBuyCompleteToast" style="display:none">
# <p>쿠키 충전 완료 되었습니다.</p>
# </div>
# <div class="tost_pop" id="lendCompleteToast" style="display:none">
# <p>대여 완료 되었습니다.</p>
# </div>
# <div class="tost_pop" id="buyCompleteToast" style="display:none">
# <p>구매 완료 되었습니다.</p>
# </div>
# <div class="tost_pop" id="lendTicketCompleteToast" style="display:none">
# <p>대여권 1개를 사용합니다.</p>
# </div>
# <div class="tost_pop" id="buyTicketCompleteToast" style="display:none">
# <p>소장권 1개를 사용합니다.</p>
# </div>
# <div class="tost_pop" id="freePurchaseCompleteToast" style="display:none">
# <p>무료 결제가 완료 되었습니다.</p>
# </div>
# <div class="tost_pop" id="addFavoriteProduct" style="display:none">
# <p>관심 목록에 추가하였습니다.</p>
# </div>
# <div class="tost_pop" id="removeFavoriteProduct" style="display:none">
# <p>관심 목록에서 삭제하였습니다.</p>
# </div>
# <hr/>
# <!-- footer -->
# <!-- footer -->
# <div class="new_footer" id="footer">
# <div class="footer_left">
# <ul class="policy_info nstore">
# <li><a href="https://member.webtoon.naver.com/policy/terms" target="_blank">네이버웹툰 이용약관</a></li>
# <li><a href="/agree/passJoinAgree.series" target="_blank">전용상품권 이용약관</a></li>
# <li><a href="https://member.webtoon.naver.com/policy/privacy" target="_blank"><strong>개인정보처리방침</strong></a></li>
# <li><a href="https://member.webtoon.naver.com/policy/youthpolicy" target="_blank">청소년보호정책</a></li>
# <li><a class="N=a:fot.help" href="https://help.naver.com/service/5629?lang=ko" target="_blank">시리즈 고객센터</a></li>
# <li><a href="https://talk.naver.com/ct/W4GRO2">스마트봇 상담</a></li>
# <li><a href="https://comic.naver.com/business/proposalGuide#business" target="_blank">광고·사업문의</a></li>
# </ul>
# <a class="service_corp" href="https://www.webtoonscorp.com">ⓒ NAVER WEBTOON Limited</a>
# </div>
# <div class="footer_right">
# <ul class="policy_info naver">
# <li><a href="https://policy.naver.com/rules/service.html" target="_blank">이용약관</a></li>
# <li><a href="https://policy.naver.com/rules/privacy.html" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://policy.naver.com/rules/disclaimer.html" target="_blank">책임의 한계와 법적고지</a></li>
# <li><a href="https://help.naver.com/index.help?lang=ko" target="_blank">고객센터</a></li>
# <li><a href="https://help.pay.naver.com/mail/form.help?alias=checkout_accuse" target="_blank">결제도용신고</a></li>
# <li><a href="https://cpc.naver.com/cpc/index.nhn" target="_blank">저작권침해신고</a></li>
# </ul>
# <a class="service_corp corp" href="https://www.navercorp.com/">ⓒ NAVER CORP.</a>
# </div>
# <div class="area_info">
# <dl class="this_card">
# <dt>사업자등록번호</dt>
# <dd>669-86-01888</dd>
# <dt>통신판매업 신고번호</dt>
# <dd>2020-성남분당B-0719 <a href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=6698601888" target="_blank">(사업자정보 확인)</a></dd>
# <dt>대표이사</dt>
# <dd>김준구</dd>
# <dt>호스팅사업자</dt>
# <dd>네이버비즈니스플랫폼</dd>
# </dl>
# <dl class="this_card">
# <dt>주소</dt>
# <dd>경기도 성남시 분당구 분당내곡로 131 판교테크원 타워1, 11-12층</dd>
# <dt>고객센터</dt>
# <dd>1588-3820</dd>
# <dt>이메일</dt>
# <dd><a href="mailto:ccnaver@naver.com">ccnaver@naver.com</a></dd>
# </dl>
# </div>
# <p class="info if_v2">모든 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단으로 이용하는 경우 관련 법령에 따라 법적 책임을 질 수 있습니다.</p>
# </div>
# <!-- //footer -->
# </div>
# <script charset="utf-8" src="/static/js/nstore/decorators/storeCommonScript-1677051170000-980952.js" type="text/javascript"></script>
# <script type="text/javascript">
# jindo.$Fn(function() {
# 	//자동완성 호출 변수 이름 변경 하면 안됩니다.(자동완성 활성화를 변수명에 depend 하게 개발 했습니다. ㅠ)
# 	oAC = new nhn.Autocomplete(
# 		// Input Manager를 생성한다.
# 		new nhn.AcInputManager(jindo.$("ac_input1")),
# 		// View Manager를 생성한다.
# 		new nhn.AcDataManager(
# 				"https://ac.series.naver.com/ac",
# 				"jsonp",
# 				"get",
# 				{
# 					q : $$.getSingle('#acSection').value + "{query}",
# 					 st : "1",
# 					 frm : "nstore",
# 					 t_koreng:1,
# 					 r_lt:'1'
# 				 }
# 		),
# 		// View Manager를 생성한다.
# 		new PlainViewManager(jindo.$("ac_view1"), jindo.$("ac_button1"), {listMax:10}),
# 		// Autocomplete 옵션으로 Form ID를 사용한다.
# 		{formId : "ac_form1"}
# 	);
#
# 	// TV스토어 홈 팝업 (영화/방송)
# 	if(typeof openTvstoreHomePopup == 'function') {
# 		openTvstoreHomePopup();
# 	}
#
# }).attach(window, 'load');
# </script>
# <!-- 동적 스크립트 구성 -->
# <script charset="utf-8" src="/static/js/web/nstore/comicNovel/detailscript-1677051170000-534860.js" type="text/javascript"></script>
# <script type="text/javascript">
# var sSocialPluginTitle = '4회차는 명전이다';
#
# function init_socialplugin() {
#     window.__splugin = SocialPlugIn_Core({
#         // nEvent Key
#         "evKey"       : "nstore",
#         // 서비스명
#         "serviceName" : "시리즈",
#         // 딤드레이어 타입(default,fixed,custom)
#         "dimmed"      : "default",
#         // 버튼 클릭후 호출되는 콜백함수
#         "onClick"     : function(button) {
#             // button = 버튼명(band:밴드보내기)
#         },
#         // 공유하기 레이어 노출 후 호출되는 콜백함수
#         "onShow"      : function() {
#         },
#         // 공유하기 레이어 닫기 후 호출되는 콜백함수
#         "onHide"      : function() {
#         }
#     });
#
#   	//window.resize 이벤트 처리 핸들러
#     window.resize = function() {
#         if (window.__splugin) {
#             window.__splugin.resize();
#         }
#     }
# }
#
# var htParameter = {
# 	// [nEvent Key]
#     evKey  : "nstore",
#     // [서비스 명]
#     servicName: "시리즈",
#     // [컨텐트 경로 FULL URL]
#     url : "https://series.naver.com/novel/detail.series?productNo=9654104",
#     // [컨텐트 제목]
#     title  : sSocialPluginTitle,
#     // [me구독 버튼]
#     me : { display : "off"},
#     // [메일 보내기 버튼]
#     mail : {
#         display : "on", // on/off
#         url     : "",
#         title   : "",
#         srvid   : "nstore",
#         srvurl  : "http://bookmark.naver.com/getRichMailTmpl.ajax?sourceUrl=" + encodeURIComponent("https://series.naver.com/novel/detail.series?productNo=9654104") // 메일 탬플릿 URL
#     },
#     // [블로그 보내기 버튼]
#     blog : {
#         display        : "on", // on/off
#         url            : "",
#         title          : "",
#         blogId         : "naver",
#         sourceType     : "101", // 개인화플러그인 소스타입(111)
#         sourceTitle    : "시리즈 > 웹소설",
#         // sourceContents : "게시물 내용",
#         sourceForm     : 2 // 스크랩 허용 여부(비허용:0,본문:1,링크:2)
#     },
#     // [카페 보내기 버튼]
#     cafe : {
#         display        : "on",
#         url            : "",
#         title          : "",
#         sourceType     : "101", // 개인화플러그인 소스타입(111)
#         sourceTitle    : "시리즈 > 웹소설",
#         // sourceContents : "게시물 내용",
#         sourceForm     : 2 // 스크랩 허용 여부(비허용:0,본문:1,링크:2)
#     },
#     // [메모 보내기 버튼]
#     memo : {
#         display : "on", // on/off
#         url     : "",
#         title   : ""
#     },
#     // [일정 보내기 버튼]
#     calendar : {
#         display : "on", // on/off
#         url     : "",
#         title   : ""
#     },
#     // [북마크 버튼]
#     bookmark : {
#         display : "on", // on/off
#         url     : "",
#         title   : ""
#     },
#     // [URL복사 버튼]
#     copyurl : {
#         display : "on", // on/off
#         url     : ""
#     },
#     // [트위터 보내기 버튼]
#     twitter : {
#         display : "on", // on/off
#         url     : "",
#         title   : ""
#     },
#     // [페이스북 보내기 버튼]
#     facebook : {
#         display : "on", // on/off
#         url     : "",
#         title   : ""
#     },
#     // [밴드 보내기 버튼]
#     band : {
#         display : "on", // on/off
#         url     : "",
#         title   : ""
#     }
# }
#
# function splugin_oninitialize() {
#     return htParameter;
# }
#
# $Fn(function() {
# 	if (true) {
# 		setTimeout(function() {
# 			jindo.LazyLoading.load("https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js?", function() {
# 				init_socialplugin();
# 			});
# 		}, 100);
# 	}
# }, this).attach(window, "load");
# </script>
# <script src="/js/lib/vue-2.6.12.min.js"></script>
# <script src="/js/lib/jquery-3.4.1.min.js"></script>
# <script src="/js/lib/js.cookie.min.js"></script>
# <script type="text/javascript">
# jQuery.noConflict();
# if (window.naver === undefined) window.naver = {};
# if (window.naver.series === undefined) window.naver.series = {};
#
# var env = 'real';
# var devEnvs = ["dev", "local", "stage"];
#
# if (devEnvs.indexOf(env) > -1) {
#     Vue.config.devtools = true;
# }
# </script>
# <script type="text/javascript">
# (function($) {
#
#     window.myInfoAutoPassApp = new Vue({
#         el: '._vueContainer',
#         data: {
#             autoPassInfo: JSON.parse('' || '{}'),
#         },
#         computed: {
#             costPassCount: function() {
#                 return formatNumber(this.autoPassInfo.autoPass.costPassCount);
#             },
#             criterion: function() {
#                 return formatNumber(this.autoPassInfo.criterion);
#             },
#             ddTextPrefix: function() {
#                 if (this.autoPassInfo.autoPassPaymentType === 'PAYMENT_DATE') {
#                     return '매월 ' + this.criterion + '일'
#                 } else if (this.autoPassInfo.autoPassPaymentType === 'PASS_COUNT') {
#                     return this.criterion + '개 미만'
#                 }
#             },
#             thisTextMainClass: function() {
#                 return [
#                     'this_text_main',
#                     (!this.autoPassInfo.joined ? '' : this.autoPassInfo.on ? 'type_green' : 'type_off')
#                 ];
#             },
#             spanClass: function() {
#                 return !this.autoPassInfo.joined ? '' : this.autoPassInfo.on ? 'text_on' : 'text_off';
#             },
#         },
#         methods: {
#             openCookieAutoPassInformationPopup: function(event) {
#                 event.preventDefault();
#                 var url = '/my/cookie/autoPass/information.series?platformType=NSTORE_PC';
#                 var popup = window.open(url, '_cookieAutoPass', 'width=450,height=731,toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=yes,resizable=yes,hotkeys=no');
#                 checkClosed(popup, window);
#             },
#             openCookieAutopassHome: function(event) {
#                 event.preventDefault();
#                 var url = '/my/cookie/autoPass/home.series?platformType=NSTORE_PC';
#                 var popup = window.open(url, '_cookieAutoPass', 'width=450,height=731,toolbar=no,location=no,directories=no,status=no,menubar=yes,scrollbars=yes,resizable=yes,hotkeys=no');
#                 checkClosed(popup, window);
#             }
#         },
#         created: function () {
#         }
#     });
#
#     function formatNumber(num) {
#         if (num === undefined || !isInt(num)) {
#             return '';
#         }
#         return num.toString().replace(/\B(?=(\d{3})+(?!\d))/g, ',');
#     }
#
#     function isInt(value) {
#         return !isNaN(value) &&
#             parseInt(Number(value)) === value &&
#             !isNaN(parseInt(value, 10));
#     }
#
# })(jQuery)
# </script>
# <script charset="utf-8" src="/static/js/nstore/my/myInfoScript-1677051170000-21304.js" type="text/javascript"></script>
# <script type="text/javascript">
# var oComicTicketHelpLayer;
# if ($('comicTicketHelpLayer')) {
# 	oComicTicketHelpLayer = new jindo.LayerManager('comicTicketHelpLayer').link('comicTicketHelpLayer').link('descComicTicketLayerButton');
# }
# var oNovelTicketHelpLayer;
# if ($('novelTicketHelpLayer')) {
# 	oNovelTicketHelpLayer = new jindo.LayerManager('novelTicketHelpLayer').link('novelTicketHelpLayer').link('descNovelTicketLayerButton');
# }
#
# var oPassHelpLayer;
# if ($('passHelpLayer')) {
# 	oPassHelpLayer = new jindo.LayerManager('passHelpLayer').link('passHelpLayer').link('descPassLayerButton');
# }
#
#
# var wel = jindo.$Element(document.body);
# var oMyInfoAreaBubbler = new jindo.Bubbler(wel.$value());
# oMyInfoAreaBubbler.attach({
# 	'openCoinChargePopup:click' : function(oEvent, elItem, params){
# 		openCoinChargePopup();
# 		oEvent.stopDefault();
# 	},
# 	'openCouponRegistPopup:click' : function(oEvent, elItem, params){
# 		openCouponRegistPopup();
# 		oEvent.stopDefault();
# 	},
# 	'openComicTicketPurchasePopup:click' : function(oEvent, elItem, params){
# 		openComicTicketPurchasePopup();
# 		oEvent.stopDefault();
# 	},
# 	'openNovelTicketPurchasePopup:click' : function(oEvent, elItem, params){
# 		openNovelTicketPurchasePopup();
# 		oEvent.stopDefault();
# 	},
# 	'makeInfoLayer:click' : function(oEvent, elItem, params){
# 		makeInfoLayer();
# 		oEvent.stopDefault();
# 	},
# 	'openPassDetailPopup:click' : function(oEvent, elItem, params){
# 		openPassDetailPopup();
# 		oEvent.stopDefault();
# 	},
# 	'openFreePassRightPopup:click' : function(oEvent, elItem, params){
# 		openFreePassRightPopup(params);
# 		oEvent.stopDefault();
# 	},
# 	'closeFreePassUsagePopup:click' : function(oEvent, elItem, params){
# 		closeFreePassUsagePopup();
# 		oEvent.stopDefault();
# 	}
# });
#
#
# function openCoinChargePopup() {
#
# 	if (jindo.$Agent().os().mac) {
# 		if (!confirm("Mac OS에서는 시리즈 콘텐츠의 구입이 가능하나 이용은 불가합니다.\n네이버 캐쉬충전을 진행하시겠습니까?\n(구입하신 콘텐츠는 Window OS 및 스마트폰/패드류에서 이용 가능)")) {
# 			return;
# 		}
# 	}
#
# 	util.checkLogin();
#
# 	switch(gLoginStatus) {
# 		case LOGIN_STATUS.LOGIN :
# 			var returnUrl = "https://series.naver.com/openerReload.series";
# 			var oWin = window.open('https://bill.naver.com/pay/pc/charge.nhn?CHNL=NV&AMT=5000&RURL=' + returnUrl, 'coinChargePopup', 'width=400,height=410,toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=no,resizable=no,hotkeys=no');
# 			oWin.focus();
# 			break;
# 		case LOGIN_STATUS.LOGOUT :
# 			util.login();
# 			break;
# 		default :
# 			alert('일시적인 오류입니다.');
# 			break;
# 	}
# }
#
# function openCouponRegistPopup(){
#
# 	util.checkLogin();
# 	switch(gLoginStatus) {
# 		case LOGIN_STATUS.LOGIN :
# 			var oWin = window.open('/coupon/regist.series', 'openCouponRegistPopup', 'width=540,height=626,toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=1,resizable=1,hotkeys=no');
# 			oWin.focus();
# 			break;
# 		case LOGIN_STATUS.LOGOUT :
# 			util.login();
# 			break;
# 		default :
# 			alert('일시적인 오류입니다.');
# 			break;
# 	}
# }
#
# function openComicTicketPurchasePopup() {
#
# 	util.checkLogin();
# 	switch(gLoginStatus) {
# 		case LOGIN_STATUS.LOGIN :
# 			var oWin = window.open('/purchase/comicTicketPurchase.series', 'comicTicketPurchasePopup', 'width=540,height=626,toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=1,resizable=1,hotkeys=no');
# 			oWin.focus();
# 			break;
# 		case LOGIN_STATUS.LOGOUT :
# 			util.login();
# 			break;
# 		default :
# 			alert('일시적인 오류입니다.');
# 			break;
# 	}
# }
#
# function openNovelTicketPurchasePopup() {
#
# 	if($Agent().os().mac){
# 		if (!confirm("구매한 컨텐츠는 Window OS 및 스마트폰/패드류에서 이용 가능합니다. (Mac OS에서는 컨텐츠 이용 불가)")) {
# 			return;
# 		}
# 	}
# 	util.checkLogin();
# 	switch(gLoginStatus) {
# 		case LOGIN_STATUS.LOGIN :
# 			var oWin = window.open('/purchase/novelTicketPurchase.series', 'novelTicketPurchasePopup', 'width=540,height=626,toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=no,resizable=no,hotkeys=no');
# 			oWin.focus();
# 			break;
# 		case LOGIN_STATUS.LOGOUT :
# 			util.login();
# 			break;
# 		default :
# 			alert('일시적인 오류입니다.');
# 			break;
# 	}
# }
#
# function openPassDetailPopup(){
#
# 	util.checkLogin();
# 	switch(gLoginStatus) {
# 		case LOGIN_STATUS.LOGIN :
# 			var oWin = window.open('/my/cookie/detailPassList.series', 'openPassDetailPopup', 'width=390,height=228,toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=1,resizable=1,hotkeys=no');
# 			oWin.focus();
# 			break;
# 		case LOGIN_STATUS.LOGOUT :
# 			util.login();
# 			break;
# 		default :
# 			alert('일시적인 오류입니다.');
# 			break;
# 	}
# }
#
# function toggleLimitPassRight(targetLink, passSeq) {
# 	var target = $Element(targetLink);
# 	if(target.hasClass('down')) { // 닫힌상태
# 		var oAjax = new $Ajax("/my/cookie/limitPassUsableContentsList.json", {
# 			method : "GET",
# 			onload : function(res) {
# 				var jsonObject = res.json();
# 				if(jsonObject.success == false){
# 					alert("일시적인 오류입니다.");
# 					return;
# 				}
#
# 				var sHtml = $Template("limitPassRightContentListTemplate").process(jsonObject);
# 				$Element(target).parent().appendHTML(sHtml);
#
# 				target.removeClass('down');
# 				target.addClass('up');
# 			}
# 		}).request({
# 			freePassSeq:passSeq
# 		});
#
# 	} else { // 오픈상태
# 		target.removeClass('up');
# 		target.addClass('down');
# 		target.next().leave();
# 	}
# }
#
# function makeInfoLayer(){
# 	var sHtml = jindo.$Template($("freeTicketInfoTemplate")).process();
# 	layerAlert(sHtml);
# }
#
# function layerAlert(template, callback){
# 	var oModalDialog = new jindo.ModalDialog({
# 		Foggy : {
# 			nShowDuration : 0,
# 			nShowOpacity : 0,
# 			nHideDuration : 0,
# 			nHideOpacity : 0
# 		},
# 		LayerPosition: {
#             sPosition: "inside-center",
#             bAuto: false
#         }
# 	});
#
# 	if(!callback) {
# 		callback = {};
# 	}
# 	oModalDialog.setLayerTemplate(template);
# 	oModalDialog.show({},callback);
# }
#
#
# function openFreePassRightPopup(params){
# 	// 기존 팝업 존재시 제거
# 	if($Element('freePassUsagePopup') != null) {
# 		$Element('freePassUsagePopup').leave();
# 	}
#
# 	var passSeq = params[0];
# 	var oAjax = new $Ajax("/my/cookie/freePassUsageList.json", {
# 		method : "GET",
# 		onload : function(res) {
# 			var jsonObject = res.json();
# 			if(jsonObject.success == false){
# 				alert("일시적인 오류입니다.");
# 				return;
# 			}
#
# 			var sHtml = $Template("freePassUsagePopupTemplate").process(jsonObject.result);
# 			$Element('wrap').appendHTML(sHtml);
# 		}
# 	}).request({
# 		freePassSeq:passSeq
# 	});
# }
#
# function closeFreePassUsagePopup() {
# 	$Element('freePassUsagePopup').leave();
# }
#
# function movePassContentsPage(targetUrl) {
# 	opener.location.href= targetUrl;
# 	window.close();
# }
#
# </script>
# <script id="freePassUsagePopupTemplate" type="text/template">
# 	<div id="freePassUsagePopup" class="poopup_area _v1" style="">
# 		<div class="progress_pop">
# 			<h3>{=passTitle}<a href="javascript:void(0)" class="button_close closeFreePassUsagePopup()"><span class="blind">닫기</span></a></h3>
# 			<!-- [D] 숫자 변경은 class="tatal_num" 안에 'em' 태그로 변경 부탁 드립니다 -->
# 			<strong class="info_total_target">대상 작품 보기 <span class="total_num">(총 <em>{=usageCount}</em>건)</span></strong>
# 			<ul class="info_title_list">
# 				{for usage in freePassUsageList}
# 				<li>
# 					<a href="{=usage.contentTargetUrlByUseLimitType}">
# 						<span>{=usage.title}</span>
# 						<span class="blind">바로가기</span>
# 					</a>
# 				</li>
# 				{/for}
# 			</ul>
# 		</div>
# 	</div>
# </script>
# <script id="limitPassRightContentListTemplate" type="text/template">
# <ul class="detail_list">
# {for content in result}
# 	<li><a href="javascript:void(0)" onclick="movePassContentsPage('{=content.contentTargetUrl}')">{=content.title}</a></li>
# {/for}
# </ul>
# </script>
# <script id="freeTicketInfoTemplate" type="text/template">
# <div class="lypop_pchprd" style="display:block;top:10px;left:10px">
# 	<div class="lypop_tit">
# 		<h3 class="pop_tit_freecupon"><span class="blind">자유이용권 안내</span></h3>
# 	</div>
# 	<h4>만화&frasl;웹소설 자유이용권</h4>
# 	<p class="txt_freecupon">&lsquo;자유이용권&rsquo;으로 이용이 가능한 상품을 정해진 기간동안 무제한으로 이용할 수 있습니다.<br>자유이용권은 1일권, 7일권, 30일권 단위로 구매가 가능하며 이용가능 기간 동안 자유이용권 상품 구매 시 이용권 차감 혜택을 받을 수 있습니다.</p>
# 	<div class="free_util_lst">
# 		<div class="free_util_cp">
# 			<span class="img_vchr"><img src="https://ssl.pstatic.net/static/nstore/img_vchr2.png" width="109" height="64" alt="만화 자유이용권"></span>
# 			<dl class="free_price">
# 				<dt>1일권</dt>
# 				<dd>2,000원<span>(<span class="ico_cuponm"></span><em>3%</em>)</span></dd>
# 				<dt>7일권</dt>
# 				<dd>4,000원<span>(<span class="ico_cuponm"></span><em>3%</em>)</span></dd>
# 				<dt>30일권</dt>
# 				<dd>9,000원<span>(<span class="ico_cuponm"></span><em>3%</em>)</span></dd>
# 			</dl>
# 		</div>
# 		<div class="free_util_cp">
# 			<span class="img_vchr"><img src="https://ssl.pstatic.net/static/nstore/img_vchr.png" width="109" height="64" alt="웹소설 자유이용권"></span>
# 			<dl class="free_price">
# 				<dt>1일권</dt>
# 				<dd>3,000원<span>(<span class="ico_cuponm"></span><em>3%</em>)</span></dd>
# 				<dt>7일권</dt>
# 				<dd>10,000원<span>(<span class="ico_cuponm"></span><em>3%</em>)</span></dd>
# 				<dt>30일권</dt>
# 				<dd>30,000원<span>(<span class="ico_cuponm"></span><em>3%</em>)</span></dd>
# 			</dl>
# 		</div>
# 	</div>
# 	<div class="ntc_area">
# 		<h2 class="blind">주의사항</h2>
# 		<ul>
# 		<li>자유이용권 표시된 콘텐츠만 이용 가능합니다.</li>
# 		<li>구매하신 자유이용권은 PC웹, 모바일웹 및 시리즈 앱에서도 동일하게 사용할 수 있습니다.</li>
# 		<li>일부 상품은 모바일 이용이 제한되니 이용 환경을 참고해 주세요.</li>
# 		</ul>
# 	</div>
# 	<div class="btn_freearea">
# 		<a href="javascript:return false;" class="dialog-close">확인</a>
# 	</div>
# 	<a href="javascript:return false;" class="lypop_cls dialog-close">레이어 팝업 닫기</a>
# </div>
# </script>
# <script id="refundDenyTemplate" type="text/template">
# <div class="lypop_pchprd2" style="display:block;top:1400px;left:10%">
# 	<div class="lypop_tit">
# 		<h3 class="pop_tit_pchcnl"><span class="blind">구매 취소 불가 안내</span></h3>
# 	</div>
# 	{if refundDenyType == 'GIVEN_COUPON_USED'}
# 		<h4 class="tlt_typ4"><span class="blind">상품 구매 시 지급된 쿠폰을 사용하여<strong>구매 취소가 불가능</strong>합니다.</span></h4>
# 	{elseif refundDenyType == 'USED_REWARD'}
# 		<h4 class="tlt_typ5"><span class="blind">이벤트로 지급된 쿠키를 사용하신 이력이 있어<strong>구매 취소가 불가능</strong>합니다.</span></h4>
# 	{else}
# 		<h4 class="tlt_typ2"><span class="blind">사용내역이 있는 상품이므로<strong>구매 취소가 불가능</strong>합니다.</span></h4>
# 		{if productTypeCode=='COMIC' || productTypeCode == 'NOVEL'}
# 			{if allVolume}
# 				<p class="sub_tit">e북, 만화, 웹소설의 전권 구매/대여 상품은 전권 취소만 가능합니다.</p>
# 			{elseif volumeCount > 1}
# 				<p class="sub_tit">e북, 만화, 웹소설의 시리즈 결제 상품은 전체 취소만 가능합니다.</p>
# 			{/if}
# 		{/if}
# 	{/if}
# ...
# 					elementList.hide();
# 					elementList.get(oEvent.nIndex).show();
# 					oEvent.stop();
# 				}
# 			});
# 			var oLayerElement = $Element(oSelectBox.getLayerElement());
# 			var nWidth = oLayerElement.show().width() + 10;
# 			oLayerElement.width(nWidth);
# 			$Element(oSelectBox.getBoxElement()).width(nWidth);
# 			oLayerElement.hide();
# 		}
# 	}
#
# 	// 이 장르의 인기 작품 영역
# 	var aGenrePolularProduct = [
#
#
#
# 		{
# 			productNo: '1610818',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20220511_263/pocket_1652238814602EahzM_JPEG/166900.jpg?type=m39',
# 			productName: '\uBCC0\uD6011990',
# 			serviceStartDate: '20200110171201',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '2337066',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20220303_289/pocket_1646277907532jOPho_JPEG/%C7%C1%B7%CE%C6%E4%BC%AD_%282%29.jpg?type=m39',
# 			productName: '\uD504\uB85C\uD398\uC11C [\uB3C5\uC810]',
# 			serviceStartDate: '20200911120004',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '2043561',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20191105_110/pocket_1572944532947jPpW2_JPEG/214671_1.jpg?type=m39',
# 			productName: '\uCCA0\uD608\uC758 \uC624\uBC84\uB85C\uB4DC',
# 			serviceStartDate: '20161002190005',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '2227858',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20190905_32/pocket_1567665103839wSdAI_JPEG/230685.jpg?type=m39',
# 			productName: '\uD658\uC0DD\uC88C',
# 			serviceStartDate: '20170307151240',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '2306873',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20160526_113/pocket_14642566032345Hafb_JPEG/-_.jpg?type=m39',
# 			productName: '\uAE30\uC801\uC744 \uADF8\uB824\uB77C!',
# 			serviceStartDate: '20180917164323',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '1572242',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20150608_146/pocket_1433724020337lTYJd_JPEG/image.JPEG?type=m39',
# 			productName: '\uD544\uB4DC',
# 			serviceStartDate: '20150608101711',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '1635150',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20141007_89/pocket_1412661748825mQrIn_JPEG/TS_good16.jpg?type=m39',
# 			productName: '\uAD7F \uBE14\uB7EC\uB4DC [\uB2E8\uD589\uBCF8]',
# 			serviceStartDate: '20141008104950',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '1800112',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20200623_114/pocket_1592891438288EvdY8_JPEG/--2.jpg?type=m39',
# 			productName: '\uADF8\uB808\uC774\uD2B8 \uC368\uC804',
# 			serviceStartDate: '20200702100007',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '2441721',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20220510_48/pocket_1652161465234A3YqL_JPEG/%B9%E4%B8%D4%B0%ED%B0%A1%B6%F3.jpg?type=m39',
# 			productName: '\uBC25\uBA39\uACE0\uAC00\uB77C',
# 			serviceStartDate: '20171011154304',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '2000179',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20170223_108/pocket_1487823209314bukI9_JPEG/__epub.jpg?type=m39',
# 			productName: '\uAC74\uCD95\uC758 \uC2E0',
# 			serviceStartDate: '20170718115310',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '2160342',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20160204_262/pocket_1454563238666E78gI_JPEG/__002.jpg?type=m39',
# 			productName: '\uD1B5 1\uBD80 [\uC7A5\uB974\uC18C\uC124]',
# 			serviceStartDate: '20160217161537',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		},
#
#
#
# 		{
# 			productNo: '1212463',
# 			thumbnailImgUrl: 'https://comicthumb-phinf.pstatic.net/20151221_26/pocket_1450680488328k0Vex_JPEG/__53.jpg?type=m39',
# 			productName: '\uC804\uB2A5\uC758 \uD314\uCC0C [\uB2E8\uD589\uBCF8]',
# 			serviceStartDate: '20151223100006',
# 			isAdultGrade: false,
# 			isSelfShieldGrade: false
# 		}
#
# 	];
# 	var  oGenrePopularProductRolling = new RelevantProductRolling({
# 		sRollingAreaId : 'genrePopularProductRollingArea',
# 		aProductData : aGenrePolularProduct,
# 		sItemTemplateId : 'relevantProductTemplate'
# 	});
#
# 	// also bought
# 	if (alsoBought = $Element("_alsoBought")) {
# 		var oAlsoDiv = alsoBought.next();
# 		var oAlsoBought = new nstore.CircularRollingManager(oAlsoDiv);
# 		oAlsoBought.setEvent();
# 	}
#
#  	// 19금 마크에 마우스 오버 이벤트 설정
#  	setAgeOverLayer();
# 	// 공통댓글
# 	var cboxLazyLoading = setInterval(function() {
# 		clearInterval(cboxLazyLoading);
# 		createCommentBox();
# 		initComment();
# 	}, 100);
#
# 	var cookie = $Cookie();
# 	var sCookieBuyYn = cookie.get("cookie_buy");
# 	if(sCookieBuyYn == 'Y'){
# 		var toastLayer = $Element("cookieBuyCompleteToast");
# 		toastLayer.show();
#
# 		setTimeout(function() {
# 			toastLayer.hide();
# 			cookie.remove("cookie_buy");
# 		}, 1000);
# 	}
#
# }, this).attach(window, 'load');
#
# function toggleLayer(targetId){
# 	$Element(targetId).toggle();
# }
# function toggleLayerByLogin(targetId){
# 	util.checkLogin();
# 	if(true){
# 		if(confirm('로그인이 필요한 서비스입니다.\n로그인 하시겠습니까?')){
# 			util.login();
# 			return;
# 		}
# 	}else{
# 		$Element(targetId).toggle();
# 	}
# }
#
# function createCommentBox(){
# 	// 공통댓글 2.0
# 	(function(htOption) {
# 		window.__htCboxOption = htOption;
# 		var s = document.createElement('script');
# 		s.type = 'text/javascript';
# 		s.charset = 'utf-8';
# 		s.src = htOption.sDomain + '/js/cbox.core.js?v=' + Math.floor(new Date().getTime() / 1200000);
# 		(document.head || document.getElementsByTagName('head')[0]).appendChild(s);
# 	})({
# 		sDomain : 'https://ssl.pstatic.net/static.cbox',
# 		sApiDomain : 'https://apis.naver.com/commentBox/cbox12',
# 		bLogin : false,
# 		sTicket : 'series5',
# 		sObjectId : '505224_0',
# 		sTemplateId: 'web',
# 		nPageSize: 15,
# 		nIndexSize: 5,
# 		sCssId: 'series_svc',
# 		htMessage: {
# 			template: {
# 				write_long_placeholder: "스포성 댓글이나 악플은 삭제될 수 있습니다.",
# 				userblock_ready_dialog_content : '이제 목록에서 댓글 및 답글을 확인할 수 없습니다.',
# 				userblock_completed_dialog_content : '해당 작성자의 댓글 우측 메뉴를 통해 차단을 해제할 수 있습니다.',
# 				userunblock_ready_dialog_content : '이제 목록에서 댓글 및 답글을 확인할 수 있습니다.',
# 				userunblock_completed_dialog_content : ''
# 			}
# 		}
# 	});
# }
#
# function initComment() {
# 	var reviewCountEl = $Element('reviewCount');
# 	if (!reviewCountEl) {
# 		return;
# 	}
#
# 	var oAjax = new $Ajax('/comments/count.json', {
# 		method: "get",
# 		onload: function (res) {
# 			var oJson = res.json();
# 			var cnt = oJson.result.count;
# 			cnt = cnt > 9999 ? '9,999+' : cnt.toString().replace(/\B(?=(\d{3})+(?!\d))/g, ",");
#
# 			reviewCountEl.html(cnt);
# 		},
# 		onerror: function () {
# 			// 리뷰 에러는 중요한 에러가 아니기 때문에 무시
# 		},
# 		async: true
# 	});
#
# 	oAjax.request({
# 		ticket: 'series5',
# 		objectId: '505224_0',
# 		lang: 'ko'
# 	});
# };
#
# function onClickCheckbox(id) {
# 	var comicNovelAllCheckbox = $Element(id);
# 	oComicNovelDetailManager._onClickCheckbox(null,comicNovelAllCheckbox);
# 	if (id == 'allchkSpan') {
# 		oComicNovelDetailManager._toggleVolumeCheckBox(null,comicNovelAllCheckbox);
# 	} else if (id == 'frstchkSpan') {
# 		oComicNovelDetailManager._changeSortOrder(null,comicNovelAllCheckbox);
# 	} else {
# 		oComicNovelDetailManager._onClickSelectedRow(null,$(id));
# 		oComicNovelDetailManager._updateSelectedVolumeCount(null,comicNovelAllCheckbox);
# 	}
# }
#
# function toggleCouponLayer(layer) {
#
# 	$Element($$.getSingle(".lypop_end_coupon")).toggle();
#
#
# 	var otherPopup = $Element('luckyCookieEventDimDiv');
# 	if(otherPopup && otherPopup.visible()) {
# 		otherPopup.hide()
# 	} else {
# 		$Element($$.getSingle(".dimmed")).toggle();
# 	}
#
# }
# </script>
# <script id="relevantProductTemplate" type="text/template">
# 	<li>
# 		<a href="/novel/detail.series?productNo={=productNo}" onclick="nclk_v2(event, 'gnr.list', '{=productNo}');"
# 		   class="pic"><span class="mask"></span><img src="{=thumbnailImgUrl}" width="39" height="59"
# 													  alt="{=productName}"
# 													  onerror="this.src='https://ssl.pstatic.net/static/nstore/thumb/noimg_book_39x59.gif'"></a>
# 		<span class="cont"><a href="/novel/detail.series?productNo={=productNo}"
# 							  onclick="nclk_v2(event, 'gnr.list', '{=productNo}');" title="{=productName}">{if isAdultGrade == true}<em
# 				class="ico n19">19세 이상가능</em>{elseif isSelfShieldGrade == true}<em
# 				class="ico ico_shield"><span class="blind">연령제한</span></em>{/if}{js util.cutStringByPixel(=productName, 230, '...')}</a><br><span>{js util.formatDate(=serviceStartDate, 'Y.m.d.')}</span></span>
# 		<span class="blk"></span>
# 	</li>
# </script>
# <script id="contentsFreePassTemplate" type="text/template">
# 	<div class="lypop_end_coupon" style="position:fixed;top:300px;left:50%;margin-left:-170px;">
#
# 		{if contentsFreePassIssue.freePassPackageCount == 1}
# 		<p>본 상품에 사용할 수 있는<br><strong>&lt;{=contentsFreePassIssue.freePassTitle}&gt;</strong> <strong>쿠키 {=contentsFreePassIssue.issueCount}개</strong> 를 받으셨습니다.<br><br>지금 바로 사용해 보세요.</p>
# 		{else}
# 		<p>본 상품에 사용할 수 있는<br><strong>&lt;{=contentsFreePassIssue.freePassTitle}&gt; 외</strong> <strong>쿠키 {=contentsFreePassIssue.issueCount}개</strong> 를 받으셨습니다.<br><br>지금 바로 사용해 보세요.</p>
# 		{/if}
# 		<a href="javascript:toggleCouponLayer()" class="lec_btn">확인</a>
# 		<span class="yh"></span>
# 		<a href="javascript:toggleCouponLayer()" class="lec_cls">쿠키 안내 팝업 닫기</a>
# 	</div>
# </script>
# <script id="contentsFreePassNotLoginedTemplate" type="text/template">
# 	<div class="lypop_end_coupon" style="position:fixed;top:300px;left:50%;margin-left:-170px;">
# 		<p>지금 로그인 하시면 <br>이 작품에 사용할 수 있는 <br>쿠키를 받으실 수 있습니다.</p>
# 		<a href="javascript:util.login();" class="lec_btn">로그인 하기</a>
# 		<span class="yh"></span>
# 		<a href="javascript:toggleCouponLayer()" class="lec_cls">쿠키 안내 팝업 닫기</a>
# 	</div>
# </script>
# <script id="contentsFreePassDimmedLayerTemplate" type="text/template">
# 	<div class="dimmed"></div>
# </script>
# <script id="volumeTicketListTemplate" type="text/template">
# <tr class="_volume_row_{=volumeNo}">
# 	<th scope="row" class="chk"></th>
# 	<td class="subj">
# 		<div>
#
# 			<span>
# 				{if subProductName != null && subProductName != ''}
# 				<strong>{js util.cutStringByByte(=volumnNameText, 44, '...')}</strong>
# 				{js util.cutStringByByte(=subProductName, 44, '...')}{else}{js util.cutStringByByte(=productName, 44, '...')}
# 				<strong>{js util.cutStringByByte(=volumnNameText, 44, '...')}</strong>
# 				{/if}
# 			</span>
# 			<em>({js util.formatDate(=lastVolumeUpdateDate, 'Y.m.d.')})</em>
# 			{if newVolume}<span class="ico_new2">NEW</span>{/if}
# 			{if rightAdditionalInfo != '' || (limitLatestVolume && (false || hasDailyFreeTicket))}
# 				<span class="bar">|</span><span class="buy_tit">{if rightAdditionalInfo != ''}<span class="point_blue">{=rightAdditionalInfo}</span>{/if}{if limitLatestVolume}<span class="point_weak">{if false && hasDailyFreeTicket}프리패스, 매일10시무료 제한{elseif false && !hasDailyFreeTicket}프리패스 제한{elseif !false && hasDailyFreeTicket}매일10시무료 제한{/if}</span>{/if}</span>
# 			{/if}
#
# 		</div>
# 	</td>
# 	<td class="prev">
# 		<div>
#
#
#
# 					{if previewYn == 'N' || !bPcPossible}
# 						<span class="ico ico_preview_off" title="미리보기">미리보기</span>
# 					{else}
# 						<a href="#" class="ico ico_preview launchViewerForPreview({=productTypeCode},{=upperOriginalProductId},{=originalProductId},false)" onclick="nclk_v2(event, 'lst.previeweach', '{=originalProductId}');" title="미리보기">미리보기</a>
# 					{/if}
#
#
# 		</div>
# 	</td>
# 	<td class="buy prime_zone">
# 		<div>
#
#
#
#
# 				{if saleYn == 'Y' || lendingYn == 'Y'}
# 					<a href="javascript:void(0);"
# 					   class="btn btn_buy3 N=a:nvx*r.abuy
# 						launchViewer({=productTypeCode},{=upperOriginalProductId},{=originalProductId},{=productNo},TICKET,false)">
# 						<strong>보기</strong>
# 					</a>
# 				{elseif lendingFree || saleFree}
# 					<a href="javascript:void(0);" id="ticket{=productNo}"
# 					   class="btn btn_buy3 cookie freeVolumn
# 						_orderFreeTicketProduct({=productTypeCode},{=productNo},{=upperOriginalProductId},{=volumeNo})
# 						_lanuchVolumnViewerAfterAction({=productTypeCode},{=upperOriginalProductId},{=originalProductId},{=productNo},TICKET,false)">
# 						<strong>무료</strong>
# 					</a>
# 				{else}
# 					<a href="javascript:void(0);" id="ticket{=productNo}" prodName="4&#54924;&#52264;&#45716; &#47749;&#51204;&#51060;&#45796;" volumnNameText="{=volumnNameText}"
# 					   class="btn btn_buy3
# 						_orderTicketProduct({=productTypeCode},{=productNo},{=upperOriginalProductId},{=volumeNo})
# 						_lanuchVolumnViewerAfterAction({=productTypeCode},{=upperOriginalProductId},{=originalProductId},{=productNo},TICKET,false)">
# 						<strong>보기</strong>
# 					</a>
# 				{/if}
#
#
# 		</div>
# 	</td>
# </tr>
# </script>
# <script type="text/javascript">
# 	(function(oData) {
# 		window.__oLikeItData = oData;
# 		var s = document.createElement("script");
# 		s.type = "text/javascript";
# 		s.charset = "utf-8";
# 		s.src = oData.domain + "/static/js/likeIt.v2.desktop.init.js?v="+ (new Date()).toDateString().replace(/\s/g,"");
# 		(document.head || document.getElementsByTagName("head")[0]).appendChild(s);
# 	})({
# 		serviceId : "NBOOKS",  // 서비스명
# 		displayId : "NSTORE",  // 노출 서비스 ID
# 		contentId : "505224",  // 컨텐츠 ID
# 		domain : "https://common.like.naver.com"  // 좋아요 서비스 도메인
# 	});
#
# 	// f/u action after sign in
# 	var signInPostBehavior = Cookies.get('signInPostBehavior');
# 	if (signInPostBehavior) {
# 		Cookies.remove('signInPostBehavior');
#
# 		var actionType = signInPostBehavior.split('.')[0];
# 		var actionTarget = signInPostBehavior.split('.')[1];
#
# 		// like
# 		if (actionType === 'like' && actionTarget === '505224') {
# 			if (window.MutationObserver) {
# 				var observer = new MutationObserver(function() {
# 					var likeItBtn = document.querySelector('.u_likeit_btn');
# 					if (!jQuery(likeItBtn).hasClass('on')) {
# 						document.querySelector('.u_likeit_btn').click();
# 					}
# 				});
# 				observer.observe(document.querySelector('.u_likeit_module'), {
# 					childList: true
# 				});
#
# 			} else {
# 				setTimeout(function() {
# 					var likeItBtn = document.querySelector('.u_likeit_btn');
# 					if (likeItBtn && !jQuery(likeItBtn).hasClass('on')) {
# 						likeItBtn.click();
# 					}
# 				}, 300)
# 			}
#
# 		// favorite
# 		} else if (actionType === 'favorite' && actionTarget === '9654104') {
# 			oFavoriteProductManager.addFavoriteProduct(null, $('productFavorite'), 2, '9654104', 'on', '');
# 		}
# 	}
#
# 	if ($(".u_likeit_module")) {
# 		jQuery('.u_likeit_module').get(0).addEventListener('click', function(e) {
# 			util.checkLogin();
#
# 			switch(gLoginStatus) {
# 				case LOGIN_STATUS.LOGIN :
# 					break;
# 				case LOGIN_STATUS.LOGOUT :
# 					var inOneMinute = new Date(new Date().getTime() + (60 * 1000));
# 					Cookies.set('signInPostBehavior', 'like.505224', {
# 						expires: inOneMinute
# 					});
#
# 					e.stopPropagation();
# 					util.login();
# 					break;
# 				default :
# 					alert('일시적인 오류입니다.');
# 			}
# 		}, true);	// To handle the custom click event, change bubbling to capturing
# 	}
#
# </script>
# <script src="/js/lib/vue-2.6.12.min.js"></script>
# <script src="/js/lib/jquery-3.4.1.min.js"></script>
# <script src="/js/lib/js.cookie.min.js"></script>
# <script type="text/javascript">
# jQuery.noConflict();
# if (window.naver === undefined) window.naver = {};
# if (window.naver.series === undefined) window.naver.series = {};
#
# var env = 'real';
# var devEnvs = ["dev", "local", "stage"];
#
# if (devEnvs.indexOf(env) > -1) {
#     Vue.config.devtools = true;
# }
# </script>
# <script type="text/javascript">
# 	window.myInfoAutoPassTooltips = new Vue({
# 		el: '.myuseinfo'
# 	});
# </script>
# <script>
# 	var SELECTED_PAYMENT_TYPE = "SELECTED_PAYMENT_TYPE";
# 	var SELECTED_CRITERION_INDEX = "SELECTED_CRITERION_INDEX";
# 	var SELECTED_AUTOPASS_INDEX = "SELECTED_AUTOPASS_INDEX";
#
# 	function checkClosed(popup, w) {
# 		var id = setInterval(function () {
# 			if (!popup || popup.closed) {
# 				clearInterval(id);
# 				w.location.reload();
#
# 				Cookies.remove(SELECTED_PAYMENT_TYPE);
# 				Cookies.remove(SELECTED_CRITERION_INDEX);
# 				Cookies.remove(SELECTED_AUTOPASS_INDEX);
# 			}
# 		}, 500);
# 	}
# </script>
# </body>
# </html>
