# %%
import json
import requests

url = "https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=series5&templateId=web&pool=cbox12&_cv=20230425152100&_callback=jQuery34105058840148780341_1682747220323&lang=ko&country=&objectId=489431_0&categoryId=&pageSize=15&indexSize=5&groupId=&listType=OBJECT&pageType=default&page=1&initialize=true&followSize=5&userType=&useAltSort=true&replyPageSize=10&_=1682747220325"
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36"
}
# GET 방식
response = requests.get(url, headers=headers)

print(response.content)
# Out:
# b'jQuery34105058840148780341_1682747220323({"success":false,"code":"3999","message":"\xec\x9e\x98\xeb\xaa\xbb\xeb\x90\x9c \xec\xa0\x91\xea\xb7\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4.","lang":"ko","country":"UNKNOWN","result":{},"date":"2023-04-29T06:45:59+0000"});'

# %% [markdown]
# ![image.png](attachment:image.png)
